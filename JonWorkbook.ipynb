# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import re
import string
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp.max_length = 5000000

# %% [markdown]
# ## Functions

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation, 
    remove words containing numbers and remove consecutive multiple white spaces.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(' +', ' ', text)
    return text

def remove_stop(doc_tokens):
    """removes stop words and returns a list of all nonstop words"""
    return [token.text for token in doc_tokens if not token.is_stop]

# %% [markdown]
# ## Clean, Tokenize, remove stop words

# %%
clean_bible = clean_text((open('Bibletxt.txt', 'r').read().replace('\n', '')))

# %%
clean_koran = clean_text((open('English-Yusuf-Ali-59.txt', 'r').read().replace('\n', '')))

# %%
clean_tanakh = clean_text((open('Tanakh1917.txt', 'r', errors = 'ignore').read().replace('\n', '')))

# %%
bible_tokens = nlp(clean_bible)

# %%
koran_tokens = nlp(clean_koran)

# %%
tanakh_tokens = nlp(clean_tanakh)

# %%
no_stop_bible = remove_stop(bible_tokens)

# %%
no_stop_koran = remove_stop(koran_tokens)

# %%
no_stop_tanakh = remove_stop(tanakh_tokens)

# %%
no_stop_koran
# Out:
# ['allah',
#  'gracious',
#  'mercifulpraise',
#  'allah',
#  'cherisher',
#  'sustainer',
#  'worldsmost',
#  'gracious',
#  'mercifulmaster',
#  'day',
#  'judgmentthee',
#  'worship',
#  'thine',
#  'aid',
#  'seekshow',
#  'straight',
#  'waythe',
#  'way',
#  'thou',
#  'hast',
#  'bestowed',
#  'thy',
#  'grace',
#  'portion',
#  'wrath',
#  'astrayalmthis',
#  'book',
#  'guidance',
#  'sure',
#  'doubt',
#  'fear',
#  'allahwho',
#  'believe',
#  'unseen',
#  'steadfast',
#  'prayer',
#  'spend',
#  'provided',
#  'themand',
#  'believe',
#  'revelation',
#  'sent',
#  'thee',
#  'sent',
#  'thy',
#  'time',
#  'hearts',
#  'assurance',
#  'hereafterthey',
#  'true',
#  'guidance',
#  'lord',
#  'prosperas',
#  'reject',
#  'faith',
#  'thou',
#  'warn',
#  'warn',
#  'believeallah',
#  'hath',
#  'set',
#  'seal',
#  'hearts',
#  'hearing',
#  'eyes',
#  'veil',
#  'great',
#  'penalty',
#  'incurof',
#  'people',
#  'believe',
#  'allah',
#  'day',
#  'believefain',
#  'deceive',
#  'allah',
#  'believe',
#  'deceive',
#  'realise',
#  'notin',
#  'hearts',
#  'disease',
#  'allah',
#  'increased',
#  'disease',
#  'grievous',
#  'penalty',
#  'incur',
#  'false',
#  'themselveswhen',
#  'said',
#  'mischief',
#  'earth',
#  'want',
#  'peaceof',
#  'surety',
#  'ones',
#  'mischief',
#  'realise',
#  'notwhen',
#  'said',
#  'believe',
#  'believe',
#  'shall',
#  'believe',
#  'fools',
#  'believe',
#  'nay',
#  'surety',
#  'fools',
#  'knowwhen',
#  'meet',
#  'believe',
#  'believe',
#  'evil',
#  'ones',
#  'jestingallah',
#  'throw',
#  'mockery',
#  'rope',
#  'trespasses',
#  'wander',
#  'like',
#  'blind',
#  'ones',
#  'frothese',
#  'bartered',
#  'guidance',
#  'error',
#  'traffic',
#  'profitless',
#  'lost',
#  'true',
#  'directiontheir',
#  'similitude',
#  'man',
#  'kindled',
#  'fire',
#  'lighted',
#  'allah',
#  'took',
#  'away',
#  'light',
#  'left',
#  'utter',
#  'darkness',
#  'seedeaf',
#  'dumb',
#  'blind',
#  'return',
#  'pathor',
#  'similitude',
#  'rainladen',
#  'cloud',
#  'sky',
#  'zones',
#  'darkness',
#  'thunder',
#  'lightning',
#  'press',
#  'fingers',
#  'ears',
#  'stunning',
#  'thunderclap',
#  'terror',
#  'death',
#  'allah',
#  'round',
#  'rejecters',
#  'faiththe',
#  'lightning',
#  'snatches',
#  'away',
#  'sight',
#  'time',
#  'light',
#  'helps',
#  'walk',
#  'darkness',
#  'grows',
#  'stand',
#  'allah',
#  'willed',
#  'away',
#  'faculty',
#  'hearing',
#  'seeing',
#  'allah',
#  'hath',
#  'power',
#  'thingso',
#  'ye',
#  'people',
#  'adore',
#  'guardianlord',
#  'created',
#  'came',
#  'ye',
#  'chance',
#  'learn',
#  'righteousnesswho',
#  'earth',
#  'couch',
#  'heavens',
#  'canopy',
#  'sent',
#  'rain',
#  'heavens',
#  'brought',
#  'forth',
#  'therewith',
#  'fruits',
#  'sustenance',
#  'set',
#  'rivals',
#  'unto',
#  'allah',
#  'ye',
#  'know',
#  'truthand',
#  'ye',
#  'doubt',
#  'revealed',
#  'time',
#  'time',
#  'servant',
#  'produce',
#  'sura',
#  'like',
#  'thereunto',
#  'witnesses',
#  'helpers',
#  'allah',
#  'doubts',
#  'truebut',
#  'ye',
#  'surety',
#  'ye',
#  'fear',
#  'fire',
#  'fuel',
#  'men',
#  'stones',
#  'prepared',
#  'reject',
#  'faithbut',
#  'glad',
#  'tidings',
#  'believe',
#  'work',
#  'righteousness',
#  'portion',
#  'gardens',
#  'beneath',
#  'rivers',
#  'flow',
#  'time',
#  'fed',
#  'fruits',
#  'therefrom',
#  'fed',
#  'given',
#  'things',
#  'similitude',
#  'companions',
#  'pure',
#  'holy',
#  'abide',
#  'everallah',
#  'disdains',
#  'use',
#  'similitude',
#  'things',
#  'lowest',
#  'highest',
#  'believe',
#  'know',
#  'truth',
#  'lord',
#  'reject',
#  'faith',
#  'means',
#  'allah',
#  'similitude',
#  'causes',
#  'stray',
#  'leads',
#  'right',
#  'path',
#  'causes',
#  'stray',
#  'forsake',
#  'paththose',
#  'break',
#  'allah´s',
#  'covenant',
#  'ratified',
#  'sunder',
#  'allah',
#  'ordered',
#  'joined',
#  'mischief',
#  'earth',
#  'cause',
#  'loss',
#  'themselveshow',
#  'ye',
#  'reject',
#  'faith',
#  'allah',
#  'seeing',
#  'ye',
#  'life',
#  'gave',
#  'life',
#  'cause',
#  'die',
#  'bring',
#  'life',
#  'ye',
#  'returnit',
#  'hath',
#  'created',
#  'things',
#  'earth',
#  'design',
#  'comprehended',
#  'heavens',
#  'gave',
#  'order',
#  'perfection',
#  'seven',
#  'firmaments',
#  'things',
#  'hath',
#  'perfect',
#  'knowledgebehold',
#  'thy',
#  'lord',
#  'said',
#  'angels',
#  'create',
#  'vicegerent',
#  'earth',
#  'said',
#  'wilt',
#  'thou',
#  'place',
#  'mischief',
#  'shed',
#  'blood',
#  'whilst',
#  'celebrate',
#  'thy',
#  'praises',
#  'glorify',
#  'thy',
#  'holy',
#  'said',
#  'know',
#  'ye',
#  'know',
#  'notand',
#  'taught',
#  'adam',
#  'names',
#  'things',
#  'placed',
#  'angels',
#  'said',
#  'tell',
#  'names',
#  'ye',
#  'rightthey',
#  'said',
#  'glory',
#  'thee',
#  'knowledge',
#  'save',
#  'thou',
#  'hast',
#  'taught',
#  'truth',
#  'thou',
#  'art',
#  'perfect',
#  'knowledge',
#  'wisdomhe',
#  'said',
#  'o',
#  'adam',
#  'tell',
#  'names',
#  'told',
#  'allah',
#  'said',
#  'tell',
#  'know',
#  'secrets',
#  'heaven',
#  'earth',
#  'know',
#  'ye',
#  'reveal',
#  'ye',
#  'concealand',
#  'behold',
#  'said',
#  'angels',
#  'bow',
#  'adam',
#  'bowed',
#  'iblis',
#  'refused',
#  'haughty',
#  'reject',
#  'faithwe',
#  'said',
#  'o',
#  'adam',
#  'dwell',
#  'thou',
#  'thy',
#  'wife',
#  'garden',
#  'eat',
#  'bountiful',
#  'things',
#  'ye',
#  'approach',
#  'tree',
#  'ye',
#  'run',
#  'harm',
#  'transgressionthen',
#  'satan',
#  'slip',
#  'garden',
#  'state',
#  'felicity',
#  'said',
#  'ye',
#  'ye',
#  'people',
#  'enmity',
#  'earth',
#  'dwellingplace',
#  'means',
#  'livelihood',
#  'timethen',
#  'learnt',
#  'adam',
#  'lord',
#  'words',
#  'inspiration',
#  'lord',
#  'turned',
#  'oftreturning',
#  'mercifulwe',
#  'said',
#  'ye',
#  'sure',
#  'comes',
#  'guidance',
#  'whosoever',
#  'follows',
#  'guidance',
#  'shall',
#  'fear',
#  'shall',
#  'grievebut',
#  'reject',
#  'faith',
#  'belie',
#  'signs',
#  'shall',
#  'companions',
#  'fire',
#  'shall',
#  'abide',
#  'thereino',
#  'children',
#  'israel',
#  'mind',
#  'special',
#  'favour',
#  'bestowed',
#  'fulfil',
#  'covenant',
#  'fulfil',
#  'covenant',
#  'fear',
#  'meand',
#  'believe',
#  'reveal',
#  'confirming',
#  'revelation',
#  'reject',
#  'faith',
#  'sell',
#  'signs',
#  'small',
#  'price',
#  'fear',
#  'aloneand',
#  'cover',
#  'truth',
#  'falsehood',
#  'conceal',
#  'truth',
#  'ye',
#  'know',
#  'isand',
#  'steadfast',
#  'prayer',
#  'practise',
#  'regular',
#  'charity',
#  'bow',
#  'heads',
#  'bow',
#  'worshipdo',
#  'ye',
#  'enjoin',
#  'right',
#  'conduct',
#  'people',
#  'forget',
#  'practise',
#  'ye',
#  'study',
#  'scripture',
#  'ye',
#  'understandnay',
#  'seek',
#  'allah´s',
#  'help',
#  'patient',
#  'perseverance',
#  'prayer',
#  'hard',
#  'bring',
#  'lowly',
#  'spiritwho',
#  'bear',
#  'mind',
#  'certainty',
#  'meet',
#  'lord',
#  'return',
#  'himchildren',
#  'israel',
#  'mind',
#  'special',
#  'favour',
#  'bestowed',
#  'preferred',
#  'messagethen',
#  'guard',
#  'day',
#  'soul',
#  'shall',
#  'avail',
#  'shall',
#  'intercession',
#  'accepted',
#  'shall',
#  'compensation',
#  'taken',
#  'shall',
#  'helped',
#  'outsideand',
#  'remember',
#  'delivered',
#  'people',
#  'pharaoh',
#  'set',
#  'hard',
#  'tasks',
#  'punishments',
#  'slaughtered',
#  'sons',
#  'let',
#  'womenfolk',
#  'live',
#  'tremendous',
#  'trial',
#  'lordand',
#  'remember',
#  'divided',
#  'sea',
#  'saved',
#  'drowned',
#  'pharaoh´s',
#  'people',
#  'sightand',
#  'remember',
#  'appointed',
#  'nights',
#  'moses',
#  'absence',
#  'ye',
#  'took',
#  'calf',
#  'worship',
#  'ye',
#  'grievous',
#  'wrongeven',
#  'forgive',
#  'chance',
#  'gratefuland',
#  'remember',
#  'gave',
#  'moses',
#  'scripture',
#  'criterion',
#  'right',
#  'wrong',
#  'chance',
#  'guided',
#  'arightand',
#  'remember',
#  'moses',
#  'said',
#  'people',
#  'o',
#  'people',
#  'ye',
#  'wronged',
#  'worship',
#  'calf',
#  'turn',
#  'repentance',
#  'maker',
#  'slay',
#  'wrongdoers',
#  'better',
#  'sight',
#  'maker',
#  'turned',
#  'forgiveness',
#  'oftreturning',
#  'mercifuland',
#  'remember',
#  'ye',
#  'said',
#  'o',
#  'moses',
#  'shall',
#  'believe',
#  'thee',
#  'allah',
#  'manifestly',
#  'ye',
#  'dazed',
#  'thunder',
#  'lighting',
#  'ye',
#  'looked',
#  'onthen',
#  'raised',
#  'death',
#  'ye',
#  'chance',
#  'gratefuland',
#  'gave',
#  'shade',
#  'clouds',
#  'sent',
#  'manna',
#  'quails',
#  'saying',
#  'eat',
#  'good',
#  'things',
#  'provided',
#  'rebelled',
#  'harm',
#  'harmed',
#  'soulsand',
#  'remember',
#  'said',
#  'enter',
#  'town',
#  'eat',
#  'plenty',
#  'ye',
#  'wish',
#  'enter',
#  'gate',
#  'humility',
#  'posture',
#  'words',
#  'shall',
#  'forgive',
#  'faults',
#  'increase',
#  'portion',
#  'goodbut',
#  'transgressors',
#  'changed',
#  'word',
#  'given',
#  'sent',
#  'transgressors',
#  'plague',
#  'heaven',
#  'infringed',
#  'command',
#  'repeatedlyand',
#  'remember',
#  'moses',
#  'prayed',
#  'water',
#  'people',
#  'said',
#  'strike',
#  'rock',
#  'thy',
#  'staff',
#  'gushed',
#  'forth',
#  'therefrom',
#  'springs',
#  'group',
#  'knew',
#  'place',
#  'water',
#  'eat',
#  'drink',
#  'sustenance',
#  'provided',
#  'allah',
#  'evil',
#  'mischief',
#  'face',
#  'earthand',
#  'remember',
#  'ye',
#  'said',
#  'o',
#  'moses',
#  'endure',
#  'kind',
#  'food',
#  'beseech',
#  'thy',
#  'lord',
#  'produce',
#  'earth',
#  'groweth',
#  'potherbs',
#  'cucumbers',
#  'garlic',
#  'lentils',
#  'onions',
#  'said',
#  'ye',
#  'exchange',
#  'better',
#  'worse',
#  'ye',
#  'town',
#  'ye',
#  'shall',
#  'find',
#  'ye',
#  'want',
#  'covered',
#  'humiliation',
#  'misery',
#  'drew',
#  'wrath',
#  'allah',
#  'went',
#  'rejecting',
#  'signs',
#  'allah',
#  'slaying',
#  'messengers',
#  'cause',
#  'rebelled',
#  'went',
#  'transgressingthose',
#  'believe',
#  'qur´an',
#  'follow',
#  'jewish',
#  'scriptures',
#  'christians',
#  'sabians',
#  'believe',
#  'allah',
#  'day',
#  'work',
#  'righteousness',
#  'shall',
#  'reward',
#  'lord',
#  'shall',
#  'fear',
#  'shall',
#  'grieveand',
#  'remember',
#  'took',
#  'covenant',
#  'raised',
#  'towering',
#  'height',
#  'mount',
#  'sinai',
#  'saying',
#  'hold',
#  'firmly',
#  'given',
#  'bring',
#  'remembrance',
#  'perchance',
#  'ye',
#  'fear',
#  'allahbut',
#  'ye',
#  'turned',
#  'grace',
#  'mercy',
#  'allah',
#  'ye',
#  'surely',
#  'lostand',
#  'ye',
#  'knew',
#  'transgressed',
#  'matter',
#  'sabbath',
#  'said',
#  'ye',
#  'apes',
#  'despised',
#  'rejectedso',
#  'example',
#  'time',
#  'posterity',
#  'lesson',
#  'fear',
#  'allahand',
#  'remember',
#  'moses',
#  'said',
#  'people',
#  'allah',
#  'commands',
#  'ye',
#  'sacrifice',
#  'heifer',
#  'said',
#  'makest',
#  'thou',
#  'laughingstock',
#  'said',
#  'allah',
#  'save',
#  'ignorant',
#  'foolthey',
#  'said',
#  'beseech',
#  'behalf',
#  'thy',
#  'lord',
#  'plain',
#  'heifer',
#  'said',
#  'says',
#  'heifer',
#  'old',
#  'young',
#  'middling',
#  'age',
#  'ye',
#  'commandedthey',
#  'said',
#  'beseech',
#  'behalf',
#  'thy',
#  'lord',
#  'plain',
#  'colour',
#  'said',
#  'says',
#  'fawncoloured',
#  'heifer',
#  'pure',
#  'rich',
#  'tone',
#  'admiration',
#  'beholdersthey',
#  'said',
#  'beseech',
#  'behalf',
#  'thy',
#  'lord',
#  'plain',
#  'heifers',
#  'alike',
#  'wish',
#  'guidance',
#  'allah',
#  'willshe',
#  'said',
#  'says',
#  'heifer',
#  'trained',
#  'till',
#  'soil',
#  'water',
#  'fields',
#  'sound',
#  'blemish',
#  'said',
#  'hast',
#  'thou',
#  'brought',
#  'truth',
#  'offered',
#  'sacrifice',
#  'goodwillremember',
#  'ye',
#  'slew',
#  'man',
#  'fell',
#  'dispute',
#  'crime',
#  'allah',
#  'bring',
#  'forth',
#  'ye',
#  'hideso',
#  'said',
#  'strike',
#  'body',
#  'piece',
#  'heifer',
#  'allah',
#  'bringeth',
#  'dead',
#  'life',
#  'showeth',
#  'signs',
#  'perchance',
#  'ye',
#  'understandthenceforth',
#  'hearts',
#  'hardened',
#  'like',
#  'rock',
#  'worse',
#  'hardness',
#  'rocks',
#  'rivers',
#  'gush',
#  'forth',
#  'split',
#  'asunder',
#  'send',
#  'forth',
#  'water',
#  'sink',
#  'fear',
#  'allah',
#  'allah',
#  'unmindful',
#  'ye',
#  'docan',
#  'ye',
#  'o',
#  'ye',
#  'men',
#  'faith',
#  'entertain',
#  'hope',
#  'believe',
#  'seeing',
#  'party',
#  'heard',
#  'word',
#  'allah',
#  'perverted',
#  'knowingly',
#  'understood',
#  'itbehold',
#  'meet',
#  'men',
#  'faith',
#  'believe',
#  'meet',
#  'private',
#  'shall',
#  'tell',
#  'allah',
#  'hath',
#  'revealed',
#  ...]

# %%
len(no_stop_bible)
# Out:
# 340751

# %%
len(no_stop_koran)
# Out:
# 64620

# %%
len(no_stop_tanakh)
# Out:
# 259241

# %%
# displacy.render(no_stop_koran, style="dep")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-9b4d7775c51f> in <module>
# ----> 1 displacy.render(no_stop_koran, style="dep")
#
# /anaconda3/lib/python3.7/site-packages/spacy/displacy/__init__.py in render(docs, style, page, minify, jupyter, options, manual)
#      46     docs = [obj if not isinstance(obj, Span) else obj.as_doc() for obj in docs]
#      47     if not all(isinstance(obj, (Doc, Span, dict)) for obj in docs):
# ---> 48         raise ValueError(Errors.E096)
#      49     renderer, converter = factories[style]
#      50     renderer = renderer(options=options)
#
# ValueError: [E096] Invalid object passed to displaCy: Can only visualize Doc or Span objects, or dicts if set to manual=True.
