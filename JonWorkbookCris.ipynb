# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import re
import string
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp.max_length = 5000000

# %% [markdown]
# ## Functions

# %%
def clean_text_1(a_list_of_filenames):
    path = '/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran'

    
    for filename in a_list_of_filenames:

        text = open(path + '/' + filename)
        str(text)
    '''Make text lowercase, remove text in square brackets, remove punctuation, 
    remove words containing numbers and remove consecutive multiple white spaces.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(' +', ' ', text)
    return text

# %%
print(clean_text_1(test_list))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9a7f9a5bb22b> in <module>
# ----> 1 print(clean_text_1(test_list))
#
# <ipython-input-17-41b35b9adc88> in clean_text_1(a_list_of_filenames)
#       9     '''Make text lowercase, remove text in square brackets, remove punctuation,
#      10     remove words containing numbers and remove consecutive multiple white spaces.'''
# ---> 11     text = text.lower()
#      12     text = re.sub('\[.*?\]', '', text)
#      13     text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'lower'

# %%
import io

f = io.BytesIO(open(directory + '/' + test_list[77], 'r'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b3d2ac611278> in <module>
#       1 import io
#       2
# ----> 3 f = io.BytesIO(open(directory + '/' + test_list[77], 'r'))
#
# NameError: name 'directory' is not defined

# %%
open('001.txt').read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-554098aeea8c> in <module>
#       1
# ----> 2 open('001.txt').read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '001.txt'

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation, 
    remove words containing numbers and remove consecutive multiple white spaces.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(' +', ' ', text)
    return text

def remove_stop(doc_tokens):
    """removes stop words and returns a list of all nonstop words"""
    return [token.text for token in doc_tokens if not token.is_stop]

# %% [markdown]
# ## Clean, Tokenize, remove stop words for Koran's Books

# %%
import os
file_list = [f for f in os.listdir('.') if os.path.isfile(os.path.join('.', f))]
print(file_list)
# Out:
# ['Bibletxt.txt', '.DS_Store', 'Tanakh1917.txt', 'JonWorkbook.ipynb', 'English-Yusuf-Ali-59.txt', 'cleaning data.ipynb', 'README.md', 'TheCreedofBuddha.txt']

# %%
import os
os.listdir('.')
# Out:
# ['Bibletxt.txt',
#  'koran_1',
#  '.DS_Store',
#  'Tanakh1917.txt',
#  'koran',
#  'JonWorkbook.ipynb',
#  'English-Yusuf-Ali-59.txt',
#  'cleaning data.ipynb',
#  'README.md',
#  'TheCreedofBuddha.txt',
#  '.ipynb_checkpoints',
#  '.git']

# %%
import os
directory = '/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran'
test_list = []
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
#         filename = open(directory + '/' + filename)
        test_list.append(filename)
#         lines = f.read()
#         print (lines[0:2])
#         continue
#     else:
#         continue

# %%
open('koran/100.txt', 'r').read()
# Out:
# 'By the racers panting.\nIgniting sparks.\nRaiding at dawn.\nRaising clouds of dust.\nStorming into the midst.\nIndeed, the human being is ungrateful to his Lord.\nAnd he bears witness to that.\nAnd he is fierce in his love of wealth.\nDoes he not know? When the contents of the graves are scattered around.\nAnd the contents of the hearts are obtained.\nTheir Lord, on that Day, is fully informed of them.'

# %%
def open_files(list_files):
    for file in list_files:
        path = '/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran'
        return open(path + '/' + filename, 'r').read()

# %%
koran_files = ['100.txt', '101.txt']

# %%
print(open_files(koran_files))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-9e6472e885b0> in <module>
# ----> 1 print(open_files(koran_files))
#
# <ipython-input-13-b2d514ef53a8> in open_files(list_files)
#       2     for file in list_files:
#       3         path = '/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran'
# ----> 4         return open(path + '/' + filename, 'r').read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran/Tanakh1917.txt'

# %%
import glob
print(glob.glob("/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran*.txt"))
# Out:
# []

# %%
# list of files in the koran folder
import os
list_file_koran = os.listdir("koran")
len(list_file_koran)
# Out:
# 114

# %%
def open_files(list_files):
    for file in list_files:
        return open(file, 'r').read()

# %%
print(open_files(list_file_koran))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-88409247f2e1> in <module>
# ----> 1 print(open_files(list_file_koran))
#
# <ipython-input-25-44d6c39add06> in open_files(list_files)
#       1 def open_files(list_files):
#       2     for file in list_files:
# ----> 3         return open(file, 'r').read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '060.txt'

# %%
import glob
path = "/Users/cristinamulas/Documents/code/nyc-mhtn-ds-060319-lectures/Mod_6/Mod_6_Project/koran"
# savepath = "/home/username/newfolder/"
for files in glob.glob(path +"*.txt"):
    infile = open(files)
    outfile = open(savepath,'w')
    a = infile.readline().split('.')
    for k in range (0,len(a)):
        print(a[0], file=outfile, end='')
infile.close()
outfile.close
print "done"

# %%
## last functions

# %%
clean_bible = clean_text((open('Bibletxt.txt', 'r').read().replace('\n', '')))

# %%
clean_koran = clean_text((open('English-Yusuf-Ali-59.txt', 'r').read().replace('\n', '')))

# %%
clean_tanakh = clean_text((open('Tanakh1917.txt', 'r', errors = 'ignore').read().replace('\n', '')))

# %%
bible_tokens = nlp(clean_bible)

# %%
koran_tokens = nlp(clean_koran)

# %%
tanakh_tokens = nlp(clean_tanakh)

# %%
no_stop_bible = remove_stop(bible_tokens)

# %%
no_stop_koran = remove_stop(koran_tokens)

# %%
no_stop_tanakh = remove_stop(tanakh_tokens)

# %%
no_stop_koran
# Out:
# ['allah',
#  'gracious',
#  'mercifulpraise',
#  'allah',
#  'cherisher',
#  'sustainer',
#  'worldsmost',
#  'gracious',
#  'mercifulmaster',
#  'day',
#  'judgmentthee',
#  'worship',
#  'thine',
#  'aid',
#  'seekshow',
#  'straight',
#  'waythe',
#  'way',
#  'thou',
#  'hast',
#  'bestowed',
#  'thy',
#  'grace',
#  'portion',
#  'wrath',
#  'astrayalmthis',
#  'book',
#  'guidance',
#  'sure',
#  'doubt',
#  'fear',
#  'allahwho',
#  'believe',
#  'unseen',
#  'steadfast',
#  'prayer',
#  'spend',
#  'provided',
#  'themand',
#  'believe',
#  'revelation',
#  'sent',
#  'thee',
#  'sent',
#  'thy',
#  'time',
#  'hearts',
#  'assurance',
#  'hereafterthey',
#  'true',
#  'guidance',
#  'lord',
#  'prosperas',
#  'reject',
#  'faith',
#  'thou',
#  'warn',
#  'warn',
#  'believeallah',
#  'hath',
#  'set',
#  'seal',
#  'hearts',
#  'hearing',
#  'eyes',
#  'veil',
#  'great',
#  'penalty',
#  'incurof',
#  'people',
#  'believe',
#  'allah',
#  'day',
#  'believefain',
# ...

# %%
len(no_stop_bible)
# Out:
# 340751

# %%
len(no_stop_koran)
# Out:
# 64620

# %%
len(no_stop_tanakh)
# Out:
# 259241

# %% [markdown]
# ## EDA

# %% [markdown]
# - Most common words - find these and create word clouds
# - Size of vocabulary - look number of unique words
# - Amount of holly words??? - most common terms ???

# %%
 # use counter example
import collections

print collections.Counter(['a', 'b', 'c', 'a', 'b', 'b'])
print collections.Counter({'a':2, 'b':3, 'c':1})
print collections.Counter(a=2, b=3, c=1)

# %%
# or make a fucntion of a dict and then sorted??

# %%
# Word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)
