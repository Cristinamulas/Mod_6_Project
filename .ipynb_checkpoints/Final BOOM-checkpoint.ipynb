# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 4.0MB/s ta 0:00:01
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import re
import string
from spacy import displacy
import os
import pandas as pd
from spacy.tokens import Token
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
import wordcloud
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import seaborn as sns
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from statistics import mean
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm import tqdm

# %%
nlp = spacy.load("en_core_web_sm")

# %%
nlp.max_length = 5000000

# %%
added_stopwords = ['thee', 'thing', 'thy', 'ye', 'thou', 'hath']
nlp.Defaults.stop_words |= {'thee', 'thing', 'thy', 'ye', 'thou', 'hath'}

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation,
    remove words containing numbers and remove consecutive multiple white spaces.'''
    text = text.lower()
    text = re.sub('\\[.*?}''"—{\\]', '', text)
#     text = re.sub('"*', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\\w*\\d\\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', ' ', text)
    text = re.sub(' +', ' ', text)
    return text
    
def remove_stop(doc_tokens):
    """removes stop words and returns list of all nonstop words that is lemmatized"""
    return [token.lemma_ for token in doc_tokens if not token.is_stop]

def open_books(directory):
    """iterates through file and opens each txt document
        creates dictionary with keys as document name and value as document text"""
    chapter_dict = {}
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            chapter_dict.update({filename : open(directory + '/' + filename, errors = 'ignore').read()})
    return chapter_dict

def join_list_of_str(list_):
    """joins list of strings as one long string"""
    space = ' '
    for i in range(len(list_)):
        return space.join(list_)
    
def clean_df(df):
    """for each row in df.text, applies clean_text function"""
    for i in df.text:
        clean_text(i)
    return i

def list_of_books(df):
    list_books = []
    for i in range(len(df.text)):
        list_books.append(df.text[i])
    return list_books

def show_wordcloud(data, title = None): 
    wordcloud = WordCloud(
        background_color='white',
        stopwords=set(STOPWORDS),
        max_words=150,
        max_font_size=50, 
        scale=4,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
    
def compound_dict(dictionary):
    new_dict = {}
    analyzer = SentimentIntensityAnalyzer()
    for k,v in dictionary.items():
        vs = analyzer.polarity_scores(v)
        new_dict.update({k:vs['compound']})
    return new_dict

def tf_idf_dict(dict_):
    corpus = list(dict_.values())
    vectorizer = TfidfVectorizer(ngram_range = (1,2))
    X = vectorizer.fit_transform(corpus)
    idf = vectorizer.idf_
    return dict(zip(vectorizer.get_feature_names(), idf))

# %%
bible_dict_unclean = open_books('bible')
tanakh_dict_unclean = open_books('tanakh')
koran_dict_unclean = open_books('koran')

# %%
tanakh_df_unclean = pd.DataFrame.from_dict(tanakh_dict_unclean, orient = 'index', columns = ['text'])
koran_df_unclean = pd.DataFrame.from_dict(koran_dict_unclean, orient = 'index', columns = ['text'])
bible_df_unclean = pd.DataFrame.from_dict(bible_dict_unclean, orient = 'index', columns = ['text'])

# %%
koran_df_clean = koran_df_unclean.applymap(lambda x: clean_text(x)) 
koran_df_no_stop = koran_df_clean.applymap(lambda x: remove_stop(nlp(x)))
koran_df = koran_df_no_stop.applymap(lambda x: list(nlp(join_list_of_str(x))))

# %%
type(koran_df_clean)

# %%
tanakh_df_clean = tanakh_df_unclean.applymap(lambda x: clean_text(x))
tanakh_df_no_stop = tanakh_df_clean.applymap(lambda x: remove_stop(nlp(x)))
tanakh_df = tanakh_df_no_stop.applymap(lambda x: list(nlp(join_list_of_str(x))))

# %%
bible_df_clean = bible_df_unclean.applymap(lambda x: clean_text(x))
bible_df_no_stop = bible_df_clean.applymap(lambda x: remove_stop(nlp(x)))
bible_df = bible_df_no_stop.applymap(lambda x: list(nlp(join_list_of_str(x))))

# %%
koran_dict = dict(koran_df_clean.text)
bible_dict = dict(bible_df_clean.text)
tanakh_dict = dict(tanakh_df_clean.text)

# %%
show_wordcloud(list_of_books(koran_df), title = 'Quran')

# %%
show_wordcloud(list_of_books(bible_df), title = 'Bible')

# %%
show_wordcloud(list_of_books(tanakh_df), title = 'Tanakh')

# %%
bible_list = list_of_books(bible_df)
koran_list = list_of_books(koran_df)
tanakh_list = list_of_books(tanakh_df)

# %%
koran_compound_dict = compound_dict(koran_dict)
koran_compound_dict
# Out:
# {'060.txt': 0.9983,
#  '074.txt': 0.3859,
#  '048.txt': 0.9984,
#  '114.txt': -0.6369,
#  '100.txt': 0.4939,
#  '101.txt': -0.714,
#  '049.txt': 0.9978,
#  '075.txt': -0.9599,
#  '061.txt': 0.9973,
#  '088.txt': -0.4831,
#  '077.txt': -0.9886,
#  '063.txt': 0.6342,
#  '103.txt': 0.8271,
#  '102.txt': 0.6369,
#  '062.txt': 0.9905,
#  '076.txt': 0.9966,
#  '089.txt': 0.6488,
#  '099.txt': 0.128,
#  '072.txt': 0.9703,
#  '066.txt': 0.9876,
#  '106.txt': 0.5423,
#  '112.txt': 0.4939,
#  '113.txt': -0.9702,
#  '107.txt': -0.8726,
#  '067.txt': 0.9961,
#  '073.txt': 0.9886,
#  '098.txt': 0.946,
#  '059.txt': 0.9934,
#  '065.txt': 0.9943,
#  '071.txt': 0.9735,
#  '111.txt': -0.6124,
#  '105.txt': -0.1531,
#  '104.txt': 0.25,
#  '110.txt': 0.8555,
#  '070.txt': 0.9831,
#  '064.txt': 0.9982,
#  '058.txt': 0.9968,
#  '003.txt': 1.0,
#  '017.txt': 0.9975,
#  '016.txt': 0.9998,
#  '002.txt': -0.9999,
#  '014.txt': 0.9988,
#  '028.txt': 0.9995,
#  '029.txt': 0.9992,
#  '001.txt': 0.9638,
#  '015.txt': 0.9938,
#  '039.txt': 0.9995,
#  '011.txt': 0.5926,
#  '005.txt': 0.9998,
#  '004.txt': 1.0,
#  '010.txt': 0.9996,
#  '038.txt': 0.9975,
#  '006.txt': -0.9363,
#  '012.txt': 0.9994,
#  '013.txt': -0.9355,
#  '007.txt': 0.9906,
#  '022.txt': 0.9997,
#  '036.txt': -0.4739,
#  '037.txt': 0.9985,
#  '023.txt': 0.9982,
#  '035.txt': 0.9965,
#  '021.txt': 0.9994,
#  '009.txt': 0.9999,
#  '008.txt': 0.9994,
#  '020.txt': 0.9953,
#  '034.txt': 0.9844,
#  '018.txt': 0.9977,
#  '030.txt': 0.9989,
#  '024.txt': 0.9999,
#  '025.txt': 0.9318,
#  '031.txt': 0.9988,
#  '019.txt': 0.9995,
#  '027.txt': 0.9998,
#  '033.txt': 0.9998,
#  '032.txt': 0.9627,
#  '026.txt': 0.9996,
#  '082.txt': 0.9418,
#  '096.txt': -0.8973,
#  '041.txt': -0.7764,
#  '055.txt': 0.9977,
#  '069.txt': 0.9899,
#  '109.txt': -0.6759,
#  '108.txt': -0.512,
#  '068.txt': -0.9829,
#  '054.txt': -0.9987,
#  '040.txt': 0.9782,
#  '097.txt': 0.8847,
#  '083.txt': -0.7186,
#  '095.txt': 0.8598,
#  '081.txt': -0.3962,
#  '056.txt': 0.993,
#  '042.txt': 0.9978,
#  '043.txt': 0.9968,
#  '057.txt': 0.9994,
#  '080.txt': 0.9168,
#  '094.txt': -0.1556,
#  '090.txt': -0.5047,
#  '084.txt': 0.2023,
#  '053.txt': 0.9911,
#  '047.txt': 0.9942,
#  '046.txt': 0.9978,
#  '052.txt': 0.9928,
#  '085.txt': 0.9442,
#  '091.txt': -0.8885,
#  '087.txt': 0.86,
#  '093.txt': 0.8637,
#  '078.txt': 0.9524,
#  '044.txt': 0.9941,
#  '050.txt': 0.9556,
#  '051.txt': 0.9883,
#  '045.txt': 0.8905,
#  '079.txt': 0.8612,
#  '092.txt': -0.6297,
#  '086.txt': 0.8402}

# %%
bible_compound_dict = compound_dict(bible_dict)

# %%
tanakh_compound_dict = compound_dict(tanakh_dict)

# %%
mean(list(koran_compound_dict.values()))
# Out:
# 0.5535605263157894

# %%
mean(list(bible_compound_dict.values()))
# Out:
# 0.5117609756097561

# %%
mean(list(tanakh_compound_dict.values()))
# Out:
# 0.2201076923076923

# %%
fig, (ax1,ax2, ax3) = plt.subplots(3,1, figsize = (30,20))
# f, (ax1, ax2, ax3) = plt.subplots(1, 2, 3, figsize=(14, 4))
# plt.subplots(1, 3, sharey= True)
# fig.set_size_inches(50, 15)
a = sns.barplot(x= sorted(list(koran_compound_dict.keys())), y = list(koran_compound_dict.values()), ax=ax1)
plt.setp(ax1.get_xticklabels(), rotation=90)
ax1.set(xlabel='Sura', ylabel='Sentiment Value')

b = sns.barplot(x= sorted(list(bible_compound_dict.keys())), y = list(bible_compound_dict.values()), ax=ax2)
plt.setp(ax2.get_xticklabels(), rotation=90)
ax2.set(xlabel='Books(Bible)', ylabel='Sentiment Value')

c = sns.barplot(x= sorted(list(tanakh_compound_dict.keys())), y = list(tanakh_compound_dict.values()), ax=ax3)
plt.setp(ax3.get_xticklabels(), rotation=90)
ax3.set(xlabel='Books(Tanakh)', ylabel='Sentiment Value')
# Out:
# [Text(0, 0.5, 'Sentiment Value'), Text(0.5, 0, 'Books(Tanakh)')]

# %%
koran_tf_idf = tf_idf_dict(koran_dict)
bible_tf_idf = tf_idf_dict(bible_dict)
tanakh_tf_idf = tf_idf_dict(tanakh_dict)

# %%
analyzer = SentimentIntensityAnalyzer()
for k,v in bible_dict.items():
    vs = analyzer.polarity_scores(v)
    print("{:-<65} {}".format(k, str(vs)))
# Out:
# Gal.txt---------------------------------------------------------- {'neg': 0.082, 'neu': 0.765, 'pos': 0.153, 'compound': 0.9998}
# Susanna.txt------------------------------------------------------ {'neg': 0.104, 'neu': 0.813, 'pos': 0.083, 'compound': -0.9922}
# Jeremiah.txt----------------------------------------------------- {'neg': 0.102, 'neu': 0.826, 'pos': 0.072, 'compound': -1.0}
# 2Thes.txt-------------------------------------------------------- {'neg': 0.051, 'neu': 0.795, 'pos': 0.154, 'compound': 0.9987}
# Amos.txt--------------------------------------------------------- {'neg': 0.105, 'neu': 0.826, 'pos': 0.069, 'compound': -0.9996}
# 2Tim.txt--------------------------------------------------------- {'neg': 0.08, 'neu': 0.747, 'pos': 0.174, 'compound': 0.9995}
# Joshua.txt------------------------------------------------------- {'neg': 0.035, 'neu': 0.913, 'pos': 0.052, 'compound': 0.9999}
# Nahum.txt-------------------------------------------------------- {'neg': 0.124, 'neu': 0.784, 'pos': 0.092, 'compound': -0.9902}
# Obadiah.txt------------------------------------------------------ {'neg': 0.066, 'neu': 0.895, 'pos': 0.04, 'compound': -0.9462}
# Exodus.txt------------------------------------------------------- {'neg': 0.043, 'neu': 0.891, 'pos': 0.066, 'compound': 1.0}
# Tobit.txt-------------------------------------------------------- {'neg': 0.089, 'neu': 0.749, 'pos': 0.162, 'compound': 1.0}
# Judges.txt------------------------------------------------------- {'neg': 0.061, 'neu': 0.871, 'pos': 0.067, 'compound': 0.9988}
# Ezra.txt--------------------------------------------------------- {'neg': 0.026, 'neu': 0.884, 'pos': 0.09, 'compound': 0.9999}
# Azar.txt--------------------------------------------------------- {'neg': 0.043, 'neu': 0.678, 'pos': 0.279, 'compound': 0.9999}
# Acts.txt--------------------------------------------------------- {'neg': 0.066, 'neu': 0.831, 'pos': 0.103, 'compound': 1.0}
# Matthew.txt------------------------------------------------------ {'neg': 0.088, 'neu': 0.814, 'pos': 0.098, 'compound': 0.9998}
# 1Peter.txt------------------------------------------------------- {'neg': 0.12, 'neu': 0.683, 'pos': 0.197, 'compound': 0.9997}
# Luke.txt--------------------------------------------------------- {'neg': 0.075, 'neu': 0.817, 'pos': 0.108, 'compound': 1.0}
# Isaiah.txt------------------------------------------------------- {'neg': 0.104, 'neu': 0.795, 'pos': 0.101, 'compound': -0.9994}
# 1Thes.txt-------------------------------------------------------- {'neg': 0.057, 'neu': 0.735, 'pos': 0.208, 'compound': 0.9999}
# Joel.txt--------------------------------------------------------- {'neg': 0.071, 'neu': 0.85, 'pos': 0.08, 'compound': 0.9845}
# Proverbs.txt----------------------------------------------------- {'neg': 0.162, 'neu': 0.674, 'pos': 0.164, 'compound': 0.6456}
# Eccl.txt--------------------------------------------------------- {'neg': 0.153, 'neu': 0.688, 'pos': 0.159, 'compound': 0.9949}
# 1Sam.txt--------------------------------------------------------- {'neg': 0.067, 'neu': 0.853, 'pos': 0.08, 'compound': 0.9999}
# 2Esdras.txt------------------------------------------------------ {'neg': 0.1, 'neu': 0.803, 'pos': 0.097, 'compound': -0.999}
# 1Kings.txt------------------------------------------------------- {'neg': 0.053, 'neu': 0.879, 'pos': 0.068, 'compound': 0.9999}
# John.txt--------------------------------------------------------- {'neg': 0.073, 'neu': 0.85, 'pos': 0.077, 'compound': 0.8504}
# Song.txt--------------------------------------------------------- {'neg': 0.027, 'neu': 0.775, 'pos': 0.197, 'compound': 1.0}
# Malachi.txt------------------------------------------------------ {'neg': 0.092, 'neu': 0.799, 'pos': 0.109, 'compound': 0.9909}
# Romans.txt------------------------------------------------------- {'neg': 0.101, 'neu': 0.715, 'pos': 0.184, 'compound': 1.0}
# 2Cor.txt--------------------------------------------------------- {'neg': 0.081, 'neu': 0.731, 'pos': 0.189, 'compound': 1.0}
# Haggai.txt------------------------------------------------------- {'neg': 0.03, 'neu': 0.894, 'pos': 0.076, 'compound': 0.9951}
# 2Mac.txt--------------------------------------------------------- {'neg': 0.105, 'neu': 0.765, 'pos': 0.131, 'compound': 0.9999}
# Nehemiah.txt----------------------------------------------------- {'neg': 0.035, 'neu': 0.881, 'pos': 0.083, 'compound': 1.0}
# 2Chron.txt------------------------------------------------------- {'neg': 0.049, 'neu': 0.861, 'pos': 0.09, 'compound': 1.0}
# Titus.txt-------------------------------------------------------- {'neg': 0.087, 'neu': 0.679, 'pos': 0.235, 'compound': 0.9995}
# Rev.txt---------------------------------------------------------- {'neg': 0.078, 'neu': 0.778, 'pos': 0.144, 'compound': 1.0}
# seal.txt--------------------------------------------------------- {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'compound': 0.91}
# Zech.txt--------------------------------------------------------- {'neg': 0.07, 'neu': 0.847, 'pos': 0.083, 'compound': 0.9985}
# Genesis.txt------------------------------------------------------ {'neg': 0.045, 'neu': 0.868, 'pos': 0.087, 'compound': 1.0}
# 1John.txt-------------------------------------------------------- {'neg': 0.12, 'neu': 0.712, 'pos': 0.169, 'compound': 0.9993}
# Hebrews.txt------------------------------------------------------ {'neg': 0.081, 'neu': 0.754, 'pos': 0.165, 'compound': 1.0}
# Esther.txt------------------------------------------------------- {'neg': 0.051, 'neu': 0.866, 'pos': 0.083, 'compound': 0.9996}
# 1Esdras.txt------------------------------------------------------ {'neg': 0.036, 'neu': 0.876, 'pos': 0.087, 'compound': 1.0}
# Psalms.txt------------------------------------------------------- {'neg': 0.103, 'neu': 0.714, 'pos': 0.184, 'compound': 1.0}
# Job.txt---------------------------------------------------------- {'neg': 0.123, 'neu': 0.765, 'pos': 0.112, 'compound': -0.9998}
# Mark.txt--------------------------------------------------------- {'neg': 0.085, 'neu': 0.834, 'pos': 0.081, 'compound': -0.9987}
# GkEsther.txt----------------------------------------------------- {'neg': 0.096, 'neu': 0.747, 'pos': 0.156, 'compound': 0.9996}
# 1Tim.txt--------------------------------------------------------- {'neg': 0.078, 'neu': 0.694, 'pos': 0.228, 'compound': 0.9999}
# Daniel.txt------------------------------------------------------- {'neg': 0.054, 'neu': 0.811, 'pos': 0.134, 'compound': 1.0}
# Judith.txt------------------------------------------------------- {'neg': 0.07, 'neu': 0.825, 'pos': 0.105, 'compound': 0.9999}
# Ruth.txt--------------------------------------------------------- {'neg': 0.034, 'neu': 0.913, 'pos': 0.053, 'compound': 0.9913}
# Micah.txt-------------------------------------------------------- {'neg': 0.097, 'neu': 0.819, 'pos': 0.084, 'compound': -0.9962}
# Num.txt---------------------------------------------------------- {'neg': 0.061, 'neu': 0.901, 'pos': 0.038, 'compound': -1.0}
# Eph.txt---------------------------------------------------------- {'neg': 0.063, 'neu': 0.757, 'pos': 0.179, 'compound': 0.9999}
# Baruch.txt------------------------------------------------------- {'neg': 0.085, 'neu': 0.774, 'pos': 0.142, 'compound': 0.9997}
# Habakkuk.txt----------------------------------------------------- {'neg': 0.124, 'neu': 0.806, 'pos': 0.07, 'compound': -0.998}
# 1Cor.txt--------------------------------------------------------- {'neg': 0.087, 'neu': 0.787, 'pos': 0.126, 'compound': 0.9999}
# Jonah.txt-------------------------------------------------------- {'neg': 0.109, 'neu': 0.782, 'pos': 0.109, 'compound': -0.9575}
# Man.txt---------------------------------------------------------- {'neg': 0.098, 'neu': 0.701, 'pos': 0.2, 'compound': 0.9947}
# Lament.txt------------------------------------------------------- {'neg': 0.156, 'neu': 0.758, 'pos': 0.086, 'compound': -0.9998}
# 1Chron.txt------------------------------------------------------- {'neg': 0.029, 'neu': 0.902, 'pos': 0.07, 'compound': 1.0}
# Wisdom.txt------------------------------------------------------- {'neg': 0.124, 'neu': 0.711, 'pos': 0.165, 'compound': 0.9999}
# James.txt-------------------------------------------------------- {'neg': 0.129, 'neu': 0.674, 'pos': 0.196, 'compound': 0.9996}
# Sirach.txt------------------------------------------------------- {'neg': 0.121, 'neu': 0.709, 'pos': 0.17, 'compound': 1.0}
# Hosea.txt-------------------------------------------------------- {'neg': 0.108, 'neu': 0.787, 'pos': 0.105, 'compound': -0.9854}
# Philemon.txt----------------------------------------------------- {'neg': 0.025, 'neu': 0.826, 'pos': 0.149, 'compound': 0.994}
# 1Mac.txt--------------------------------------------------------- {'neg': 0.08, 'neu': 0.816, 'pos': 0.104, 'compound': 1.0}
# Zeph.txt--------------------------------------------------------- {'neg': 0.12, 'neu': 0.797, 'pos': 0.084, 'compound': -0.9956}
# 2John.txt-------------------------------------------------------- {'neg': 0.027, 'neu': 0.753, 'pos': 0.22, 'compound': 0.997}
# Col.txt---------------------------------------------------------- {'neg': 0.052, 'neu': 0.775, 'pos': 0.173, 'compound': 0.9998}
# 3John.txt-------------------------------------------------------- {'neg': 0.04, 'neu': 0.738, 'pos': 0.222, 'compound': 0.9949}
# 2Kings.txt------------------------------------------------------- {'neg': 0.058, 'neu': 0.885, 'pos': 0.058, 'compound': -0.9961}
# Lev.txt---------------------------------------------------------- {'neg': 0.07, 'neu': 0.878, 'pos': 0.052, 'compound': -1.0}
# 2Peter.txt------------------------------------------------------- {'neg': 0.082, 'neu': 0.781, 'pos': 0.137, 'compound': 0.998}
# Bel.txt---------------------------------------------------------- {'neg': 0.085, 'neu': 0.832, 'pos': 0.083, 'compound': -0.5108}
# Let.txt---------------------------------------------------------- {'neg': 0.107, 'neu': 0.81, 'pos': 0.083, 'compound': -0.9949}
# Deut.txt--------------------------------------------------------- {'neg': 0.081, 'neu': 0.818, 'pos': 0.101, 'compound': 0.9999}
# 2Sam.txt--------------------------------------------------------- {'neg': 0.066, 'neu': 0.859, 'pos': 0.075, 'compound': 0.9993}
# Jude.txt--------------------------------------------------------- {'neg': 0.117, 'neu': 0.705, 'pos': 0.178, 'compound': 0.9934}
# Ezekiel.txt------------------------------------------------------ {'neg': 0.071, 'neu': 0.851, 'pos': 0.078, 'compound': 0.9993}
# Philip.txt------------------------------------------------------- {'neg': 0.062, 'neu': 0.736, 'pos': 0.203, 'compound': 0.9999}

# %%
analyzer = SentimentIntensityAnalyzer()
for k,v in tanakh_dict.items():
    vs = analyzer.polarity_scores(v)
    print("{:-<65} {}".format(k, str(vs)))
# Out:
# Job(Iyov).txt---------------------------------------------------- {'neg': 0.123, 'neu': 0.765, 'pos': 0.112, 'compound': -0.9998}
# Jeremiah.txt----------------------------------------------------- {'neg': 0.102, 'neu': 0.826, 'pos': 0.072, 'compound': -1.0}
# Amos.txt--------------------------------------------------------- {'neg': 0.105, 'neu': 0.826, 'pos': 0.069, 'compound': -0.9996}
# Chronicles2(HaYamim2).txt---------------------------------------- {'neg': 0.049, 'neu': 0.861, 'pos': 0.09, 'compound': 1.0}
# Joshua.txt------------------------------------------------------- {'neg': 0.035, 'neu': 0.913, 'pos': 0.052, 'compound': 0.9999}
# Nahum.txt-------------------------------------------------------- {'neg': 0.123, 'neu': 0.784, 'pos': 0.092, 'compound': -0.9899}
# Zephaniah.txt---------------------------------------------------- {'neg': 0.12, 'neu': 0.797, 'pos': 0.083, 'compound': -0.9957}
# Genesis(J).txt--------------------------------------------------- {'neg': 0.045, 'neu': 0.868, 'pos': 0.087, 'compound': 1.0}
# Judges.txt------------------------------------------------------- {'neg': 0.061, 'neu': 0.871, 'pos': 0.067, 'compound': 0.9988}
# Samuel2.txt------------------------------------------------------ {'neg': 0.066, 'neu': 0.859, 'pos': 0.075, 'compound': 0.9993}
# Ezra.txt--------------------------------------------------------- {'neg': 0.028, 'neu': 0.914, 'pos': 0.058, 'compound': 0.9997}
# Exodus(J).txt---------------------------------------------------- {'neg': 0.043, 'neu': 0.891, 'pos': 0.066, 'compound': 1.0}
# Samuel1.txt------------------------------------------------------ {'neg': 0.067, 'neu': 0.852, 'pos': 0.08, 'compound': 0.9999}
# Lamentations(Eichah).txt----------------------------------------- {'neg': 0.155, 'neu': 0.758, 'pos': 0.086, 'compound': -0.9998}
# Obidiah.txt------------------------------------------------------ {'neg': 0.066, 'neu': 0.895, 'pos': 0.04, 'compound': -0.9462}
# Isaiah.txt------------------------------------------------------- {'neg': 0.104, 'neu': 0.795, 'pos': 0.101, 'compound': -0.9994}
# Deuteronomy(J).txt----------------------------------------------- {'neg': 0.081, 'neu': 0.818, 'pos': 0.101, 'compound': 0.9999}
# Joel.txt--------------------------------------------------------- {'neg': 0.074, 'neu': 0.856, 'pos': 0.07, 'compound': 0.8724}
# Numbers(J).txt--------------------------------------------------- {'neg': 0.061, 'neu': 0.901, 'pos': 0.038, 'compound': -1.0}
# Zechariah.txt---------------------------------------------------- {'neg': 0.07, 'neu': 0.847, 'pos': 0.082, 'compound': 0.9985}
# Proverbs(Mishlei).txt-------------------------------------------- {'neg': 0.162, 'neu': 0.674, 'pos': 0.164, 'compound': 0.6456}
# Malachi.txt------------------------------------------------------ {'neg': 0.092, 'neu': 0.799, 'pos': 0.109, 'compound': 0.9909}
# SongofSongs(ShirHaShirim).txt------------------------------------ {'neg': 0.026, 'neu': 0.783, 'pos': 0.191, 'compound': 0.9999}
# Haggai.txt------------------------------------------------------- {'neg': 0.03, 'neu': 0.894, 'pos': 0.076, 'compound': 0.9951}
# Ecclesiastes(Kohelet).txt---------------------------------------- {'neg': 0.153, 'neu': 0.688, 'pos': 0.159, 'compound': 0.9949}
# Nehemiah.txt----------------------------------------------------- {'neg': 0.036, 'neu': 0.899, 'pos': 0.065, 'compound': 0.9999}
# Kings1.txt------------------------------------------------------- {'neg': 0.053, 'neu': 0.879, 'pos': 0.068, 'compound': 0.9999}
# Esther.txt------------------------------------------------------- {'neg': 0.051, 'neu': 0.866, 'pos': 0.083, 'compound': 0.9996}
# Kings2.txt------------------------------------------------------- {'neg': 0.058, 'neu': 0.885, 'pos': 0.058, 'compound': -0.9961}
# Daniel.txt------------------------------------------------------- {'neg': 0.054, 'neu': 0.811, 'pos': 0.134, 'compound': 1.0}
# Ruth.txt--------------------------------------------------------- {'neg': 0.034, 'neu': 0.913, 'pos': 0.053, 'compound': 0.9913}
# Micah.txt-------------------------------------------------------- {'neg': 0.097, 'neu': 0.819, 'pos': 0.083, 'compound': -0.9962}
# Habakkuk.txt----------------------------------------------------- {'neg': 0.124, 'neu': 0.806, 'pos': 0.07, 'compound': -0.998}
# Psalms(Tehillim).txt--------------------------------------------- {'neg': 0.105, 'neu': 0.708, 'pos': 0.187, 'compound': 1.0}
# Jonah.txt-------------------------------------------------------- {'neg': 0.105, 'neu': 0.817, 'pos': 0.078, 'compound': -0.9945}
# Chronicles1(HaYamim1).txt---------------------------------------- {'neg': 0.029, 'neu': 0.901, 'pos': 0.07, 'compound': 1.0}
# Hosea.txt-------------------------------------------------------- {'neg': 0.108, 'neu': 0.787, 'pos': 0.105, 'compound': -0.9854}
# Leviticus(J).txt------------------------------------------------- {'neg': 0.07, 'neu': 0.878, 'pos': 0.053, 'compound': -1.0}
# Ezekiel.txt------------------------------------------------------ {'neg': 0.071, 'neu': 0.851, 'pos': 0.078, 'compound': 0.9993}

# %%
analyzer = SentimentIntensityAnalyzer()
for k,v in koran_dict.items():
    vs = analyzer.polarity_scores(v)
    print("{:-<65} {}".format(k, str(vs)))
# Out:
# 060.txt---------------------------------------------------------- {'neg': 0.064, 'neu': 0.724, 'pos': 0.212, 'compound': 0.9983}
# 074.txt---------------------------------------------------------- {'neg': 0.091, 'neu': 0.816, 'pos': 0.093, 'compound': 0.3859}
# 048.txt---------------------------------------------------------- {'neg': 0.118, 'neu': 0.657, 'pos': 0.225, 'compound': 0.9984}
# 114.txt---------------------------------------------------------- {'neg': 0.152, 'neu': 0.797, 'pos': 0.051, 'compound': -0.6369}
# 100.txt---------------------------------------------------------- {'neg': 0.065, 'neu': 0.844, 'pos': 0.092, 'compound': 0.4939}
# 101.txt---------------------------------------------------------- {'neg': 0.152, 'neu': 0.774, 'pos': 0.074, 'compound': -0.714}
# 049.txt---------------------------------------------------------- {'neg': 0.114, 'neu': 0.653, 'pos': 0.233, 'compound': 0.9978}
# 075.txt---------------------------------------------------------- {'neg': 0.13, 'neu': 0.794, 'pos': 0.076, 'compound': -0.9599}
# 061.txt---------------------------------------------------------- {'neg': 0.059, 'neu': 0.707, 'pos': 0.233, 'compound': 0.9973}
# 088.txt---------------------------------------------------------- {'neg': 0.119, 'neu': 0.786, 'pos': 0.096, 'compound': -0.4831}
# 077.txt---------------------------------------------------------- {'neg': 0.182, 'neu': 0.73, 'pos': 0.088, 'compound': -0.9886}
# 063.txt---------------------------------------------------------- {'neg': 0.087, 'neu': 0.784, 'pos': 0.128, 'compound': 0.6342}
# 103.txt---------------------------------------------------------- {'neg': 0.076, 'neu': 0.561, 'pos': 0.363, 'compound': 0.8271}
# 102.txt---------------------------------------------------------- {'neg': 0.102, 'neu': 0.724, 'pos': 0.174, 'compound': 0.6369}
# 062.txt---------------------------------------------------------- {'neg': 0.083, 'neu': 0.705, 'pos': 0.213, 'compound': 0.9905}
# 076.txt---------------------------------------------------------- {'neg': 0.077, 'neu': 0.716, 'pos': 0.207, 'compound': 0.9966}
# 089.txt---------------------------------------------------------- {'neg': 0.123, 'neu': 0.736, 'pos': 0.141, 'compound': 0.6488}
# 099.txt---------------------------------------------------------- {'neg': 0.068, 'neu': 0.846, 'pos': 0.086, 'compound': 0.128}
# 072.txt---------------------------------------------------------- {'neg': 0.081, 'neu': 0.781, 'pos': 0.137, 'compound': 0.9703}
# 066.txt---------------------------------------------------------- {'neg': 0.077, 'neu': 0.761, 'pos': 0.162, 'compound': 0.9876}
# 106.txt---------------------------------------------------------- {'neg': 0.127, 'neu': 0.636, 'pos': 0.237, 'compound': 0.5423}
# 112.txt---------------------------------------------------------- {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4939}
# 113.txt---------------------------------------------------------- {'neg': 0.382, 'neu': 0.585, 'pos': 0.033, 'compound': -0.9702}
# 107.txt---------------------------------------------------------- {'neg': 0.216, 'neu': 0.743, 'pos': 0.041, 'compound': -0.8726}
# 067.txt---------------------------------------------------------- {'neg': 0.089, 'neu': 0.733, 'pos': 0.178, 'compound': 0.9961}
# 073.txt---------------------------------------------------------- {'neg': 0.084, 'neu': 0.743, 'pos': 0.174, 'compound': 0.9886}
# 098.txt---------------------------------------------------------- {'neg': 0.094, 'neu': 0.717, 'pos': 0.189, 'compound': 0.946}
# 059.txt---------------------------------------------------------- {'neg': 0.146, 'neu': 0.657, 'pos': 0.197, 'compound': 0.9934}
# 065.txt---------------------------------------------------------- {'neg': 0.071, 'neu': 0.745, 'pos': 0.185, 'compound': 0.9943}
# 071.txt---------------------------------------------------------- {'neg': 0.085, 'neu': 0.761, 'pos': 0.155, 'compound': 0.9735}
# 111.txt---------------------------------------------------------- {'neg': 0.173, 'neu': 0.759, 'pos': 0.068, 'compound': -0.6124}
# 105.txt---------------------------------------------------------- {'neg': 0.07, 'neu': 0.874, 'pos': 0.056, 'compound': -0.1531}
# 104.txt---------------------------------------------------------- {'neg': 0.112, 'neu': 0.76, 'pos': 0.128, 'compound': 0.25}
# 110.txt---------------------------------------------------------- {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.8555}
# 070.txt---------------------------------------------------------- {'neg': 0.125, 'neu': 0.688, 'pos': 0.186, 'compound': 0.9831}
# 064.txt---------------------------------------------------------- {'neg': 0.071, 'neu': 0.683, 'pos': 0.246, 'compound': 0.9982}
# 058.txt---------------------------------------------------------- {'neg': 0.115, 'neu': 0.689, 'pos': 0.196, 'compound': 0.9968}
# 003.txt---------------------------------------------------------- {'neg': 0.122, 'neu': 0.672, 'pos': 0.206, 'compound': 1.0}
# 017.txt---------------------------------------------------------- {'neg': 0.12, 'neu': 0.73, 'pos': 0.15, 'compound': 0.9975}
# 016.txt---------------------------------------------------------- {'neg': 0.103, 'neu': 0.72, 'pos': 0.177, 'compound': 0.9998}
# 002.txt---------------------------------------------------------- {'neg': 0.158, 'neu': 0.719, 'pos': 0.123, 'compound': -0.9999}
# 014.txt---------------------------------------------------------- {'neg': 0.107, 'neu': 0.715, 'pos': 0.178, 'compound': 0.9988}
# 028.txt---------------------------------------------------------- {'neg': 0.094, 'neu': 0.75, 'pos': 0.156, 'compound': 0.9995}
# 029.txt---------------------------------------------------------- {'neg': 0.11, 'neu': 0.707, 'pos': 0.183, 'compound': 0.9992}
# 001.txt---------------------------------------------------------- {'neg': 0.042, 'neu': 0.664, 'pos': 0.294, 'compound': 0.9638}
# 015.txt---------------------------------------------------------- {'neg': 0.098, 'neu': 0.764, 'pos': 0.138, 'compound': 0.9938}
# 039.txt---------------------------------------------------------- {'neg': 0.12, 'neu': 0.679, 'pos': 0.2, 'compound': 0.9995}
# 011.txt---------------------------------------------------------- {'neg': 0.146, 'neu': 0.71, 'pos': 0.144, 'compound': 0.5926}
# 005.txt---------------------------------------------------------- {'neg': 0.123, 'neu': 0.698, 'pos': 0.179, 'compound': 0.9998}
# 004.txt---------------------------------------------------------- {'neg': 0.123, 'neu': 0.663, 'pos': 0.213, 'compound': 1.0}
# 010.txt---------------------------------------------------------- {'neg': 0.1, 'neu': 0.736, 'pos': 0.164, 'compound': 0.9996}
# 038.txt---------------------------------------------------------- {'neg': 0.115, 'neu': 0.725, 'pos': 0.16, 'compound': 0.9975}
# 006.txt---------------------------------------------------------- {'neg': 0.12, 'neu': 0.756, 'pos': 0.125, 'compound': -0.9363}
# 012.txt---------------------------------------------------------- {'neg': 0.098, 'neu': 0.761, 'pos': 0.142, 'compound': 0.9994}
# 013.txt---------------------------------------------------------- {'neg': 0.137, 'neu': 0.742, 'pos': 0.121, 'compound': -0.9355}
# 007.txt---------------------------------------------------------- {'neg': 0.118, 'neu': 0.753, 'pos': 0.129, 'compound': 0.9906}
# 022.txt---------------------------------------------------------- {'neg': 0.107, 'neu': 0.7, 'pos': 0.193, 'compound': 0.9997}
# 036.txt---------------------------------------------------------- {'neg': 0.118, 'neu': 0.768, 'pos': 0.114, 'compound': -0.4739}
# 037.txt---------------------------------------------------------- {'neg': 0.118, 'neu': 0.713, 'pos': 0.169, 'compound': 0.9985}
# 023.txt---------------------------------------------------------- {'neg': 0.116, 'neu': 0.725, 'pos': 0.159, 'compound': 0.9982}
# 035.txt---------------------------------------------------------- {'neg': 0.132, 'neu': 0.683, 'pos': 0.185, 'compound': 0.9965}
# 021.txt---------------------------------------------------------- {'neg': 0.106, 'neu': 0.729, 'pos': 0.166, 'compound': 0.9994}
# 009.txt---------------------------------------------------------- {'neg': 0.114, 'neu': 0.672, 'pos': 0.213, 'compound': 0.9999}
# 008.txt---------------------------------------------------------- {'neg': 0.122, 'neu': 0.683, 'pos': 0.195, 'compound': 0.9994}
# 020.txt---------------------------------------------------------- {'neg': 0.096, 'neu': 0.786, 'pos': 0.117, 'compound': 0.9953}
# 034.txt---------------------------------------------------------- {'neg': 0.109, 'neu': 0.759, 'pos': 0.132, 'compound': 0.9844}
# 018.txt---------------------------------------------------------- {'neg': 0.102, 'neu': 0.769, 'pos': 0.128, 'compound': 0.9977}
# 030.txt---------------------------------------------------------- {'neg': 0.098, 'neu': 0.732, 'pos': 0.17, 'compound': 0.9989}
# 024.txt---------------------------------------------------------- {'neg': 0.092, 'neu': 0.698, 'pos': 0.211, 'compound': 0.9999}
# 025.txt---------------------------------------------------------- {'neg': 0.122, 'neu': 0.74, 'pos': 0.137, 'compound': 0.9318}
# 031.txt---------------------------------------------------------- {'neg': 0.09, 'neu': 0.706, 'pos': 0.204, 'compound': 0.9988}
# 019.txt---------------------------------------------------------- {'neg': 0.077, 'neu': 0.757, 'pos': 0.167, 'compound': 0.9995}
# 027.txt---------------------------------------------------------- {'neg': 0.079, 'neu': 0.732, 'pos': 0.189, 'compound': 0.9998}
# 033.txt---------------------------------------------------------- {'neg': 0.099, 'neu': 0.685, 'pos': 0.216, 'compound': 0.9998}
# 032.txt---------------------------------------------------------- {'neg': 0.085, 'neu': 0.802, 'pos': 0.113, 'compound': 0.9627}
# 026.txt---------------------------------------------------------- {'neg': 0.097, 'neu': 0.741, 'pos': 0.162, 'compound': 0.9996}
# 082.txt---------------------------------------------------------- {'neg': 0.092, 'neu': 0.733, 'pos': 0.175, 'compound': 0.9418}
# 096.txt---------------------------------------------------------- {'neg': 0.132, 'neu': 0.79, 'pos': 0.077, 'compound': -0.8973}
# 041.txt---------------------------------------------------------- {'neg': 0.13, 'neu': 0.737, 'pos': 0.133, 'compound': -0.7764}
# 055.txt---------------------------------------------------------- {'neg': 0.15, 'neu': 0.631, 'pos': 0.219, 'compound': 0.9977}
# 069.txt---------------------------------------------------------- {'neg': 0.065, 'neu': 0.82, 'pos': 0.115, 'compound': 0.9899}
# 109.txt---------------------------------------------------------- {'neg': 0.201, 'neu': 0.799, 'pos': 0.0, 'compound': -0.6759}
# 108.txt---------------------------------------------------------- {'neg': 0.249, 'neu': 0.633, 'pos': 0.118, 'compound': -0.512}
# 068.txt---------------------------------------------------------- {'neg': 0.135, 'neu': 0.765, 'pos': 0.1, 'compound': -0.9829}
# 054.txt---------------------------------------------------------- {'neg': 0.227, 'neu': 0.669, 'pos': 0.104, 'compound': -0.9987}
# 040.txt---------------------------------------------------------- {'neg': 0.149, 'neu': 0.681, 'pos': 0.171, 'compound': 0.9782}
# 097.txt---------------------------------------------------------- {'neg': 0.021, 'neu': 0.81, 'pos': 0.169, 'compound': 0.8847}
# 083.txt---------------------------------------------------------- {'neg': 0.115, 'neu': 0.792, 'pos': 0.093, 'compound': -0.7186}
# 095.txt---------------------------------------------------------- {'neg': 0.129, 'neu': 0.633, 'pos': 0.239, 'compound': 0.8598}
# 081.txt---------------------------------------------------------- {'neg': 0.074, 'neu': 0.866, 'pos': 0.06, 'compound': -0.3962}
# 056.txt---------------------------------------------------------- {'neg': 0.09, 'neu': 0.77, 'pos': 0.14, 'compound': 0.993}
# 042.txt---------------------------------------------------------- {'neg': 0.121, 'neu': 0.703, 'pos': 0.176, 'compound': 0.9978}
# 043.txt---------------------------------------------------------- {'neg': 0.111, 'neu': 0.739, 'pos': 0.149, 'compound': 0.9968}
# 057.txt---------------------------------------------------------- {'neg': 0.089, 'neu': 0.69, 'pos': 0.221, 'compound': 0.9994}
# 080.txt---------------------------------------------------------- {'neg': 0.107, 'neu': 0.756, 'pos': 0.138, 'compound': 0.9168}
# 094.txt---------------------------------------------------------- {'neg': 0.17, 'neu': 0.689, 'pos': 0.141, 'compound': -0.1556}
# 090.txt---------------------------------------------------------- {'neg': 0.121, 'neu': 0.795, 'pos': 0.084, 'compound': -0.5047}
# 084.txt---------------------------------------------------------- {'neg': 0.091, 'neu': 0.811, 'pos': 0.099, 'compound': 0.2023}
# 053.txt---------------------------------------------------------- {'neg': 0.104, 'neu': 0.738, 'pos': 0.158, 'compound': 0.9911}
# 047.txt---------------------------------------------------------- {'neg': 0.116, 'neu': 0.714, 'pos': 0.169, 'compound': 0.9942}
# 046.txt---------------------------------------------------------- {'neg': 0.124, 'neu': 0.691, 'pos': 0.185, 'compound': 0.9978}
# 052.txt---------------------------------------------------------- {'neg': 0.107, 'neu': 0.732, 'pos': 0.162, 'compound': 0.9928}
# 085.txt---------------------------------------------------------- {'neg': 0.095, 'neu': 0.739, 'pos': 0.166, 'compound': 0.9442}
# 091.txt---------------------------------------------------------- {'neg': 0.148, 'neu': 0.755, 'pos': 0.097, 'compound': -0.8885}
# 087.txt---------------------------------------------------------- {'neg': 0.066, 'neu': 0.779, 'pos': 0.155, 'compound': 0.86}
# 093.txt---------------------------------------------------------- {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.8637}
# 078.txt---------------------------------------------------------- {'neg': 0.081, 'neu': 0.787, 'pos': 0.132, 'compound': 0.9524}
# 044.txt---------------------------------------------------------- {'neg': 0.119, 'neu': 0.691, 'pos': 0.19, 'compound': 0.9941}
# 050.txt---------------------------------------------------------- {'neg': 0.132, 'neu': 0.71, 'pos': 0.158, 'compound': 0.9556}
# 051.txt---------------------------------------------------------- {'neg': 0.121, 'neu': 0.707, 'pos': 0.172, 'compound': 0.9883}
# 045.txt---------------------------------------------------------- {'neg': 0.102, 'neu': 0.772, 'pos': 0.125, 'compound': 0.8905}
# 079.txt---------------------------------------------------------- {'neg': 0.107, 'neu': 0.766, 'pos': 0.127, 'compound': 0.8612}
# 092.txt---------------------------------------------------------- {'neg': 0.16, 'neu': 0.698, 'pos': 0.142, 'compound': -0.6297}
# 086.txt---------------------------------------------------------- {'neg': 0.09, 'neu': 0.748, 'pos': 0.162, 'compound': 0.8402}

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below
number_topics = 5
number_words = 10

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(test)

# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)

# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ad062fa7e482> in <module>
#      20
#      21 # Fit and transform the processed titles
# ---> 22 count_data = count_vectorizer.fit_transform(test)
#      23
#      24 # Create and fit the LDA model
#
# NameError: name 'test' is not defined

# %%
test = join_list_of_str(list(koran_dict.values()))

# %%
def df_scattertext_prep(df, bookname):
    df.reset_index().columns = ['chapters', 'text']
#     df.columns = ['chapters', 'text']
    df['book'] = bookname
    return df

# %%
df_try = koran_df.reset_index().head()

# %%
df_try.head()
# Out:
#      index                                               text   book
# 0  060.txt  [o, believe, enemy, enemy, supporter, offer, a...  Koran
# 1  074.txt  [o, enrobe, arise, warn, magnify, lord, purify...  Koran
# 2  048.txt  [grant, conspicuous, victory, god, forgive, si...  Koran
# 3  114.txt  [seek, refuge, lord, mankind, king, mankind, g...  Koran
# 4  100.txt  [racer, pant, ignite, spark, raid, dawn, raise...  Koran

# %%
df_try['chapter'] = df_try.index

# %%
df_try.set_index('chapter', inplace=True)

# %%
df_try.head()
# Out:
#            index                                               text   book
# chapter
# 0        060.txt  [o, believe, enemy, enemy, supporter, offer, a...  Koran
# 1        074.txt  [o, enrobe, arise, warn, magnify, lord, purify...  Koran
# 2        048.txt  [grant, conspicuous, victory, god, forgive, si...  Koran
# 3        114.txt  [seek, refuge, lord, mankind, king, mankind, g...  Koran
# 4        100.txt  [racer, pant, ignite, spark, raid, dawn, raise...  Koran

# %%
df_try2.reset_index('chapter', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e41156f380c1> in <module>
# ----> 1 df_try2.reset_index('chapter', inplace=True)
#
# NameError: name 'df_try2' is not defined

# %%
df_scattertext_prep(koran_df, 'Koran')
# Out:
#                                                       text   book
# 060.txt  [o, believe, enemy, enemy, supporter, offer, a...  Koran
# 074.txt  [o, enrobe, arise, warn, magnify, lord, purify...  Koran
# 048.txt  [grant, conspicuous, victory, god, forgive, si...  Koran
# 114.txt  [seek, refuge, lord, mankind, king, mankind, g...  Koran
# 100.txt  [racer, pant, ignite, spark, raid, dawn, raise...  Koran
# 101.txt  [shocker, shocker, explain, shocker, day, peop...  Koran
# 049.txt  [o, believe, place, opinion, god, messenger, f...  Koran
# 075.txt  [swear, day, resurrection, swear, blame, soul,...  Koran
# 061.txt  [heaven, earth, praise, god, almighty, wise, o...  Koran
# 088.txt  [come, news, overwhelming, face, day, shame, l...  Koran
# 077.txt  [unleashed, succession, storming, turbulently,...  Koran
# 063.txt  [hypocrite, come, bear, witness, god, messenge...  Koran
# 103.txt  [time, human, loss, believe, good, work, encou...  Koran
# 102.txt  [abundance, distract, visit, graveyard, know, ...  Koran
# 062.txt  [heaven, earth, glorifie, god, sovereign, holy...  Koran
# 076.txt  [come, man, period, time, mention, create, man...  Koran
# 089.txt  [daybreak, night, odd, night, recede, oath, ra...  Koran
# 099.txt  [earth, shake, quake, earth, bring, load, man,...  Koran
# 072.txt  [reveal, band, jinn, listen, say, hear, wondro...  Koran
# 066.txt  [o, prophet, prohibit, god, permit, seek, wife...  Koran
# 106.txt  [security, quraish, security, winter, summer, ...  Koran
# 112.txt     [god, god, absolute, beget, beget, comparable]  Koran
# 113.txt  [refuge, lord, daybreak, evil, create, evil, d...  Koran
# 107.txt  [consider, deny, religion, mistreat, orphan, e...  Koran
# 067.txt  [bless, hand, sovereignty, power, create, deat...  Koran
# 073.txt  [o, enwrap, stay, night, little, half, reduce,...  Koran
# 098.txt  [disbelieve, people, scripture, polytheist, ap...  Koran
# 059.txt  [glorify, god, exist, heaven, earth, almighty,...  Koran
# 065.txt  [o, prophet, divorce, woman, divorce, period, ...  Koran
# 071.txt  [send, noah, people, warn, people, come, painf...  Koran
# ...                                                    ...    ...
# 054.txt  [hour, draw, near, moon, split, miracle, turn,...  Koran
# 040.txt  [ha, meem, send, scripture, god, almighty, omn...  Koran
# 097.txt  [send, night, decree, convey, night, decree, n...  Koran
# 083.txt  [woe, defrauder, measure, people, measure, wei...  Koran
# 095.txt  [fig, olive, mount, sinai, safe, land, create,...  Koran
# 081.txt  [sun, roll, star, dim, mountain, set, motion, ...  Koran
# 056.txt  [inevitable, occur, occurrence, denial, bring,...  Koran
# 042.txt  [ha, meem, ayn, see, qaf, inspire, —, god, alm...  Koran
# 043.txt  [ha, meem, book, make, thing, clear, arabic, q...  Koran
# 057.txt  [glorify, god, heaven, earth, almighty, wise, ...  Koran
# 080.txt  [frown, turn, away, blind, man, approach, know...  Koran
# 094.txt  [soothe, heart, lift, burden, weigh, raise, re...  Koran
# 090.txt  [swear, land, resident, land, father, father, ...  Koran
# 084.txt  [sky, rupture, hearken, lord, earth, level, ca...  Koran
# 053.txt  [star, go, friend, go, astray, err, speak, des...  Koran
# 047.txt  [disbelieve, repel, path, god, —, nullify, wor...  Koran
# 046.txt  [ha, meem, send, scripture, god, honorable, wi...  Koran
# 052.txt  [mount, book, inscribe, publish, scroll, frequ...  Koran
# 085.txt  [sky, constellation, promise, day, witness, wi...  Koran
# 091.txt  [sun, radiance, moon, follow, day, reveal, nig...  Koran
# 087.txt  [praise, lord, high, create, regulate, measure...  Koran
# 093.txt  [morning, light, night, settle, lord, abandon,...  Koran
# 078.txt  [ask, great, event, disagree, surely, find, ce...  Koran
# 044.txt  [ha, meem, enlightening, scripture, reveal, bl...  Koran
# 050.txt  [qaf, glorious, quran, marvel, warner, come, d...  Koran
# 051.txt  [spreader, spread, carry, load, move, gently, ...  Koran
# 045.txt  [ha, meem, revelation, book, god, exalt, wise,...  Koran
# 079.txt  [snatch, violently, remove, gently, glide, smo...  Koran
# 092.txt  [night, cover, day, reveal, create, male, fema...  Koran
# 086.txt  [sky, attariq, let, know, attariq, pierce, sta...  Koran
#
# [114 rows x 2 columns]
