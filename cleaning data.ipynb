# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
np.random.seed(0)

# %%
# open file koran
with open('Tanakh1917.txt', 'rb') as f:
    koran = f.readlines()

# %%
# open file buddha
with open('TheCreedofBuddha.txt', 'rb') as f:
    buddha = f.readlines()

# %%
# open file bible
with open('Bibletxt.txt', 'rb') as f:
    bible = f.readlines()

# %%
# Out:
# [b'Skip to main content\n',
#  b'\n',
#  b'\tweb\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\ttexts\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\tmovies\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\taudio\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\tsoftware\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\timage\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\tlogo\xe2\x80\xa8\n',
#  b'\tsearch\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\xe2\x80\xa8\n',
#  b'\t\xe2\x80\xa8upload\xe2\x80\xa8UPLOAD\xe2\x80\xa8\n',
#  b'\t\xe2\x80\xa8person\xe2\x80\xa8SIGN IN\xe2\x80\xa8\n',
#  b'ABOUT\xe2\x80\xa8\xc2\xa0CONTACT\xe2\x80\xa8\xc2\xa0BLOG\xe2\x80\xa8\xc2\xa0PROJECTS\xe2\x80\xa8\xc2\xa0HELP\xe2\x80\xa8\xc2\xa0DONATE\xe2\x80\xa8\xc2\xa0JOBS\xe2\x80\xa8\xc2\xa0VOLUNTEER\xe2\x80\xa8\xc2\xa0PEOPLE\xe2\x80\xa8\n',
#  b'Full text of "The Holy Bible American Standard Version ( 1901)"\n',
#  b'See other formats\n',
#  b'\n',
#  b'The American Standard Version of the Holy \n',
#  b'\n',
#  b'Bible (1901) \n',
#  b'\n',
#  b'by \n',
#  b'\n',
#  b'Anonymous \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'About The American Standard Version of the Holy Bible ( 1901) by Anonymous \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'Title: \n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1901) \n',
#  b'\n',
#  b'\n',
#  b'URL: \n',
#  b'Author(s): \n',
#  b'Source: \n',
#  b'Rights: \n',
#  b'Date Created: \n',
#  b'CCEL Subjects: \n',
#  b'LC Call no: \n',
#  b'LC Subjects: \n',
#  b'\n',
#  b'\n',
#  b'http://www.ccel.org/ccel/bible/asv.html \n',
#  b'Anonymous \n',
#  b'http://www.ebible.org \n',
#  b'Public Domain \n',
#  b'2002-06-09 \n',
#  b'All; Bible \n',
#  b'BS185 \n',
#  b'The Bible \n',
#  b'\n',
#  b'Modern texts and versions \n',
#  b'English \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'Table of Contents \n',
#  b'\n',
#  b'About This Book p. ii \n',
#  b'\n',
#  b'Preface to the Edition of A.D. 1885 p. 1 \n',
#  b'\n',
#  b'Preface to the American Edition p. 7 \n',
#  b'\n',
#  b'Old Testament p. 13 \n',
#  b'\n',
#  b'Genesis p. 13 \n',
#  b'\n',
#  b'Genesis 1 p. 13 \n',
#  b'\n',
#  b'Genesis 2 p. 14 \n',
#  b'\n',
#  b'Genesis 3 p. 16 \n',
#  b'\n',
#  b'Genesis 4 p. 17 \n',
#  b'\n',
#  b'Genesis 5 p. 18 \n',
#  b'\n',
#  b'Genesis 6 p. 20 \n',
#  b'\n',
#  b'Genesis 7 p. 21 \n',
#  b'\n',
#  b'Genesis 8 p. 22 \n',
#  b'\n',
#  b'Genesis 9 p. 24 \n',
#  b'\n',
#  b'Genesis 10 p. 25 \n',
#  b'\n',
#  b'Genesis 11 p. 26 \n',
#  b'\n',
#  b'Genesis 12 p. 28 \n',
#  b'\n',
#  b'Genesis 13 p. 29 \n',
#  b'\n',
#  b'Genesis 14 p. 30 \n',
#  b'\n',
#  b'Genesis 15 p. 31 \n',
#  b'\n',
#  b'Genesis 16 p. 32 \n',
#  b'\n',
#  b'Genesis 17 p. 33 \n',
#  b'\n',
#  b'Genesis 18 p. 35 \n',
#  b'\n',
#  b'Genesis 19 p. 37 \n',
#  b'\n',
#  b'Genesis 20 p. 39 \n',
#  b'\n',
#  b'Genesis 21 p. 40 \n',
#  b'\n',
#  b'Genesis 22 p. 41 \n',
#  b'\n',
#  b'Genesis 23 p. 43 \n',
#  b'\n',
#  b'Genesis 24 p. 44 \n',
#  b'\n',
#  b'Genesis 25 p. 47 \n',
#  b'\n',
#  b'Genesis 26 p. 49 \n',
#  b'\n',
#  b'Genesis 27 p. 51 \n',
#  b'\n',
#  b'Genesis 28 p. 53 \n',
#  b'\n',
#  b'Genesis 29 p. 55 \n',
#  b'\n',
#  b'Genesis 30 p. 56 \n',
#  b'\n',
#  b'iii \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'Genesis 31 p. 59 \n',
#  b'\n',
#  b'Genesis 32 p. 61 \n',
#  b'\n',
#  b'Genesis 33 p. 63 \n',
#  b'\n',
#  b'Genesis 34 p. 64 \n',
#  b'\n',
#  b'Genesis 35 p. 66 \n',
#  b'\n',
#  b'Genesis 36 p. 67 \n',
#  b'\n',
#  b'Genesis 37 p. 69 \n',
#  b'\n',
#  b'Genesis 38 p. 71 \n',
#  b'\n',
#  b'Genesis 39 p. 73 \n',
#  b'\n',
#  b'Genesis 40 p. 74 \n',
#  b'\n',
#  b'Genesis 41 p. 75 \n',
#  b'\n',
#  b'Genesis 42 p. 78 \n',
#  b'\n',
#  b'Genesis 43 p. 80 \n',
#  b'\n',
#  b'Genesis 44 p. 82 \n',
#  b'\n',
#  b'Genesis 45 p. 84 \n',
#  b'\n',
#  b'Genesis 46 p. 85 \n',
#  b'\n',
#  b'Genesis 47 p. 87 \n',
#  b'\n',
#  b'Genesis 48 p. 89 \n',
#  b'\n',
#  b'Genesis 49 p. 90 \n',
#  b'\n',
#  b'Genesis 50 p. 93 \n',
#  b'\n',
#  b'Exodus p. 94 \n',
#  b'\n',
#  b'Exodus 1 p. 94 \n',
#  b'\n',
#  b'Exodus 2 p. 95 \n',
#  b'\n',
#  b'Exodus 3 p. 97 \n',
#  b'\n',
#  b'Exodus 4 p. 98 \n',
#  b'\n',
#  b'Exodus 5 p. 100 \n',
#  b'\n',
#  b'Exodus 6 p. 101 \n',
#  b'\n',
#  b'Exodus 7 p. 103 \n',
#  b'\n',
#  b'Exodus 8 p. 104 \n',
#  b'\n',
#  b'Exodus 9 p. 106 \n',
#  b'\n',
#  b'Exodus 10 p. 108 \n',
#  b'\n',
#  b'Exodus 11 p. 1 10 \n',
#  b'\n',
#  b'Exodus 12 p. 1 10 \n',
#  b'\n',
#  b'Exodus 13 p. 1 13 \n',
#  b'\n',
#  b'Exodus 14 p. 1 15 \n',
#  b'\n',
#  b'Exodus 15 p. 1 16 \n',
#  b'\n',
#  b'Exodus 16 p. 1 18 \n',
#  b'\n',
#  b'Exodus 17 p. 121 \n',
#  b'\n',
#  b'Exodus 18 p. 121 \n',
#  b'\n',
#  b'Exodus 19 p. 123 \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'IV \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'Exodus 20 p. 124 \n',
#  b'\n',
#  b'Exodus 21 p. 126 \n',
#  b'\n',
#  b'Exodus 22 p. 128 \n',
#  b'\n',
#  b'Exodus 23 p. 129 \n',
#  b'\n',
#  b'Exodus 24 p. 131 \n',
#  b'\n',
#  b'Exodus 25 p. 132 \n',
#  b'\n',
#  b'Exodus 26 p. 134 \n',
#  b'\n',
#  b'Exodus 27 p. 136 \n',
#  b'\n',
#  b'Exodus 28 p. 137 \n',
#  b'\n',
#  b'Exodus 29 p. 140 \n',
#  b'\n',
#  b'Exodus 30 p. 142 \n',
#  b'\n',
#  b'Exodus 31 p. 144 \n',
#  b'\n',
#  b'Exodus 32 p. 145 \n',
#  b'\n',
#  b'Exodus 33 p. 148 \n',
#  b'\n',
#  b'Exodus 34 p. 149 \n',
#  b'\n',
#  b'Exodus 35 p. 151 \n',
#  b'\n',
#  b'Exodus 36 p. 153 \n',
#  b'\n',
#  b'Exodus 37 p. 155 \n',
#  b'\n',
#  b'Exodus 38 p. 156 \n',
#  b'\n',
#  b'Exodus 39 p. 158 \n',
#  b'\n',
#  b'Exodus 40 p. 160 \n',
#  b'\n',
#  b'Leviticus p. 162 \n',
#  b'\n',
#  b'Leviticus 1 p. 162 \n',
#  b'\n',
#  b'Leviticus 2 p. 163 \n',
#  b'\n',
#  b'Leviticus 3 p. 164 \n',
#  b'\n',
#  b'Leviticus 4 p. 165 \n',
#  b'\n',
#  b'Leviticus 5 p. 167 \n',
#  b'\n',
#  b'Leviticus 6 p. 168 \n',
#  b'\n',
#  b'Leviticus 7 p. 170 \n',
#  b'\n',
#  b'Leviticus 8 p. 172 \n',
#  b'\n',
#  b'Leviticus 9 p. 174 \n',
#  b'\n',
#  b'Leviticus 10 p. 176 \n',
#  b'\n',
#  b'Leviticus 11 p. 177 \n',
#  b'\n',
#  b'Leviticus 12 p. 179 \n',
#  b'\n',
#  b'Leviticus 13 p. 180 \n',
#  b'\n',
#  b'Leviticus 14 p. 183 \n',
#  b'\n',
#  b'Leviticus 15 p. 186 \n',
#  b'\n',
#  b'Leviticus 16 p. 188 \n',
#  b'\n',
#  b'Leviticus 17 p. 190 \n',
#  b'\n',
#  b'Leviticus 18 p. 191 \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'Leviticus 19 p. 193 \n',
#  b'\n',
#  b'Leviticus 20 p. 195 \n',
#  b'\n',
#  b'Leviticus 21 p. 197 \n',
#  b'\n',
#  b'Leviticus 22 p. 198 \n',
#  b'\n',
#  b'Leviticus 23 p. 200 \n',
#  b'\n',
#  b'Leviticus 24 p. 202 \n',
#  b'\n',
#  b'Leviticus 25 p. 203 \n',
#  b'\n',
#  b'Leviticus 26 p. 206 \n',
#  b'\n',
#  b'Leviticus 27 p. 209 \n',
#  b'\n',
#  b'Numbers p. 210 \n',
#  b'\n',
#  b'Numbers 1 p. 21 1 \n',
#  b'\n',
#  b'Numbers 2 p. 213 \n',
#  b'\n',
#  b'Numbers 3 p. 215 \n',
#  b'\n',
#  b'Numbers 4 p. 218 \n',
#  b'\n',
#  b'Numbers 5 p. 221 \n',
#  b'\n',
#  b'Numbers 6 p. 223 \n',
#  b'\n',
#  b'Numbers 7 p. 224 \n',
#  b'\n',
#  b'Numbers 8 p. 228 \n',
#  b'\n',
#  b'Numbers 9 p. 229 \n',
#  b'\n',
#  b'Numbers 10 p. 231 \n',
#  b'\n',
#  b'Numbers 11 p. 233 \n',
#  b'\n',
#  b'Numbers 12 p. 235 \n',
#  b'\n',
#  b'Numbers 13 p. 236 \n',
#  b'\n',
#  b'Numbers 14 p. 237 \n',
#  b'\n',
#  b'Numbers 15 p. 240 \n',
#  b'\n',
#  b'Numbers 16 p. 242 \n',
#  b'\n',
#  b'Numbers 17 p. 244 \n',
#  b'\n',
#  b'Numbers 18 p. 245 \n',
#  b'\n',
#  b'Numbers 19 p. 247 \n',
#  b'\n',
#  b'Numbers 20 p. 248 \n',
#  b'\n',
#  b'Numbers 21 p. 250 \n',
#  b'\n',
#  b'Numbers 22 p. 252 \n',
#  b'\n',
#  b'Numbers 23 p. 255 \n',
#  b'\n',
#  b'Numbers 24 p. 257 \n',
#  b'\n',
#  b'Numbers 25 p. 259 \n',
#  b'\n',
#  b'Numbers 26 p. 260 \n',
#  b'\n',
#  b'Numbers 27 p. 263 \n',
#  b'\n',
#  b'Numbers 28 p. 264 \n',
#  b'\n',
#  b'Numbers 29 p. 266 \n',
#  b'\n',
#  b'Numbers 30 p. 268 \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'VI \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1901) \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'Anonymous \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'Numbers 31 p. 269 \n',
#  b'\n',
#  b'Numbers 32 p. 272 \n',
#  b'\n',
#  b'Numbers 33 p. 274 \n',
#  b'\n',
#  b'Numbers 34 p. 276 \n',
#  b'\n',
#  b'Numbers 35 p. 278 \n',
#  b'\n',
#  b'Numbers 36 p. 280 \n',
#  b'\n',
#  b'Deuteronomy p. 280 \n',
#  b'\n',
#  b'Deuteronomy 1 p. 281 \n',
#  b'\n',
#  b'Deuteronomy 2 p. 283 \n',
#  b'\n',
#  b'Deuteronomy 3 p. 285 \n',
#  b'\n',
#  b'Deuteronomy 4 p. 287 \n',
#  b'\n',
#  b'Deuteronomy 5 p. 290 \n',
#  b'\n',
#  b'Deuteronomy 6 p. 291 \n',
#  b'\n',
#  b'Deuteronomy 7 p. 293 \n',
#  b'\n',
#  b'Deuteronomy 8 p. 295 \n',
#  b'\n',
#  b'Deuteronomy 9 p. 296 \n',
#  b'\n',
#  b'Deuteronomy 10 p. 298 \n',
#  b'\n',
#  b'Deuteronomy 11 p. 299 \n',
#  b'\n',
#  b'Deuteronomy 12 p. 301 \n',
#  b'\n',
#  b'Deuteronomy 13 p. 303 \n',
#  b'\n',
#  b'Deuteronomy 14 p. 304 \n',
#  b'\n',
#  b'Deuteronomy 15 p. 305 \n',
#  b'\n',
#  b'Deuteronomy 16 p. 307 \n',
#  b'\n',
#  b'Deuteronomy 17 p. 308 \n',
#  b'\n',
#  b'Deuteronomy 18 p. 310 \n',
#  b'\n',
#  b'Deuteronomy 19 p. 31 1 \n',
#  b'\n',
#  b'Deuteronomy 20 p. 312 \n',
#  b'\n',
#  b'Deuteronomy 21 p. 313 \n',
#  b'\n',
#  b'Deuteronomy 22 p. 315 \n',
#  b'\n',
#  b'Deuteronomy 23 p. 317 \n',
#  b'\n',
#  b'Deuteronomy 24 p. 318 \n',
#  b'\n',
#  b'Deuteronomy 25 p. 320 \n',
#  b'\n',
#  b'Deuteronomy 26 p. 321 \n',
#  b'\n',
#  b'Deuteronomy 27 p. 322 \n',
#  b'\n',
#  b'Deuteronomy 28 p. 324 \n',
#  b'\n',
#  b'Deuteronomy 29 p. 328 \n',
#  b'\n',
#  b'Deuteronomy 30 p. 329 \n',
#  b'\n',
#  b'Deuteronomy 31 p. 331 \n',
#  b'\n',
#  b'Deuteronomy 32 p. 332 \n',
#  b'\n',
#  b'Deuteronomy 33 p. 337 \n',
#  b'\n',
#  b'vii \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'Deuteronomy 34 p. 340 \n',
#  b'\n',
#  b'Joshua p. 341 \n',
#  b'\n',
#  b'Joshua 1 p. 341 \n',
#  b'\n',
#  b'Joshua 2 p. 342 \n',
#  b'\n',
#  b'Joshua 3 p. 344 \n',
#  b'\n',
#  b'Joshua 4 p. 345 \n',
#  b'\n',
#  b'Joshua 5 p. 346 \n',
#  b'\n',
#  b'Joshua 6 p. 347 \n',
#  b'\n',
#  b'Joshua 7 p. 349 \n',
#  b'\n',
#  b'Joshua 8 p. 351 \n',
#  b'\n',
#  b'Joshua 9 p. 353 \n',
#  b'\n',
#  b'Joshua 10 p. 355 \n',
#  b'\n',
#  b'Joshua 11 p. 357 \n',
#  b'\n',
#  b'Joshua 12 p. 359 \n',
#  b'\n',
#  b'Joshua 13 p. 360 \n',
#  b'\n',
#  b'Joshua 14 p. 362 \n',
#  b'\n',
#  b'Joshua 15 p. 363 \n',
#  b'\n',
#  b'Joshua 16 p. 365 \n',
#  b'\n',
#  b'Joshua 17 p. 366 \n',
#  b'\n',
#  b'Joshua 18 p. 367 \n',
#  b'\n',
#  b'Joshua 19 p. 369 \n',
#  b'\n',
#  b'Joshua 20 p. 371 \n',
#  b'\n',
#  b'Joshua 21 p. 372 \n',
#  b'\n',
#  b'Joshua 22 p. 374 \n',
#  b'\n',
#  b'Joshua 23 p. 377 \n',
#  b'\n',
#  b'Joshua 24 p. 378 \n',
#  b'\n',
#  b'Judges p. 380 \n',
#  b'\n',
#  b'Judges 1 p. 380 \n',
#  b'\n',
#  b'Judges 2 p. 382 \n',
#  b'\n',
#  b'Judges 3 p. 383 \n',
#  b'\n',
#  b'Judges 4 p. 385 \n',
#  b'\n',
#  b'Judges 5 p. 387 \n',
#  b'\n',
#  b'Judges 6 p. 390 \n',
#  b'\n',
#  b'Judges 7 p. 392 \n',
#  b'\n',
#  b'Judges 8 p. 394 \n',
#  b'\n',
#  b'Judges 9 p. 396 \n',
#  b'\n',
#  b'Judges 10 p. 399 \n',
#  b'\n',
#  b'Judges 11 p. 400 \n',
#  b'\n',
#  b'Judges 12 p. 403 \n',
#  b'\n',
#  b'Judges 13 p. 404 \n',
#  b'\n',
#  b'viii \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'Judges 14 p. 405 \n',
#  b'\n',
#  b'Judges 15 p. 407 \n',
#  b'\n',
#  b'Judges 16 p. 408 \n',
#  b'\n',
#  b'Judges 17 p. 410 \n',
#  b'\n',
#  b'Judges 18 p. 41 1 \n',
#  b'\n',
#  b'Judges 19 p. 413 \n',
#  b'\n',
#  b'Judges 20 p. 415 \n',
#  b'\n',
#  b'Judges 21 p. 418 \n',
#  b'\n',
#  b'Ruth p. 419 \n',
#  b'\n',
#  b'Ruth 1 p. 419 \n',
#  b'\n',
#  b'Ruth 2 p. 421 \n',
#  b'\n',
#  b'Ruth 3 p. 422 \n',
#  b'\n',
#  b'Ruth 4 p. 423 \n',
#  b'\n',
#  b'1 Samuel p. 425 \n',
#  b'\n',
#  b'1 Samuel 1 p. 425 \n',
#  b'\n',
#  b'1 Samuel 2 p. 426 \n',
#  b'\n',
#  b'1 Samuel 3 p. 429 \n',
#  b'\n',
#  b'1 Samuel 4 p. 430 \n',
#  b'\n',
#  b'1 Samuel 5 p. 431 \n',
#  b'\n',
#  b'1 Samuel 6 p. 432 \n',
#  b'\n',
#  b'1 Samuel 7 p. 434 \n',
#  b'\n',
#  b'1 Samuel 8 p. 435 \n',
#  b'\n',
#  b'1 Samuel 9 p. 436 \n',
#  b'\n',
#  b'1 Samuel 10 p. 438 \n',
#  b'\n',
#  b'1 Samuel 11 p. 439 \n',
#  b'\n',
#  b'1 Samuel 12 p. 441 \n',
#  b'\n',
#  b'1 Samuel 13 p. 442 \n',
#  b'\n',
#  b'1 Samuel 14 p. 444 \n',
#  b'\n',
#  b'1 Samuel 15 p. 447 \n',
#  b'\n',
#  b'1 Samuel 16 p. 449 \n',
#  b'\n',
#  b'1 Samuel 17 p. 450 \n',
#  b'\n',
#  b'1 Samuel 18 p. 453 \n',
#  b'\n',
#  b'1 Samuel 19 p. 455 \n',
#  b'\n',
#  b'1 Samuel 20 p. 457 \n',
#  b'\n',
#  b'1 Samuel 21 p. 459 \n',
#  b'\n',
#  b'1 Samuel 22 p. 460 \n',
#  b'\n',
#  b'1 Samuel 23 p. 462 \n',
#  b'\n',
#  b'1 Samuel 24 p. 464 \n',
#  b'\n',
#  b'1 Samuel 25 p. 465 \n',
#  b'\n',
#  b'1 Samuel 26 p. 468 \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'IX \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'1 Samuel 27 p. 469 \n',
#  b'\n',
#  b'1 Samuel 28 p. 470 \n',
#  b'\n',
#  b'1 Samuel 29 p. 472 \n',
#  b'\n',
#  b'1 Samuel 30 p. 473 \n',
#  b'\n',
#  b'1 Samuel 31 p. 475 \n',
#  b'\n',
#  b'2 Samuel p. 475 \n',
#  b'\n',
#  b'2 Samuel 1 p. 475 \n',
#  b'\n',
#  b'2 Samuel 2 p. 477 \n',
#  b'\n',
#  b'2 Samuel 3 p. 479 \n',
#  b'\n',
#  b'2 Samuel 4 p. 481 \n',
#  b'\n',
#  b'2 Samuel 5 p. 482 \n',
#  b'\n',
#  b'2 Samuel 6 p. 484 \n',
#  b'\n',
#  b'2 Samuel 7 p. 485 \n',
#  b'\n',
#  b'2 Samuel 8 p. 487 \n',
#  b'\n',
#  b'2 Samuel 9 p. 488 \n',
#  b'\n',
#  b'2 Samuel 10 p. 489 \n',
#  b'\n',
#  b'2 Samuel 11 p. 490 \n',
#  b'\n',
#  b'2 Samuel 12 p. 492 \n',
#  b'\n',
#  b'2 Samuel 13 p. 494 \n',
#  b'\n',
#  b'2 Samuel 14 p. 496 \n',
#  b'\n',
#  b'2 Samuel 15 p. 498 \n',
#  b'\n',
#  b'2 Samuel 16 p. 500 \n',
#  b'\n',
#  b'2 Samuel 17 p. 502 \n',
#  b'\n',
#  b'2 Samuel 18 p. 504 \n',
#  b'\n',
#  b'2 Samuel 19 p. 506 \n',
#  b'\n',
#  b'2 Samuel 20 p. 508 \n',
#  b'\n',
#  b'2 Samuel 21 p. 510 \n',
#  b'\n',
#  b'2 Samuel 22 p. 512 \n',
#  b'\n',
#  b'2 Samuel 23 p. 515 \n',
#  b'\n',
#  b'2 Samuel 24 p. 517 \n',
#  b'\n',
#  b'1 Kings p. 519 \n',
#  b'\n',
#  b'1 Kings 1 p. 519 \n',
#  b'\n',
#  b'1 Kings 2 p. 522 \n',
#  b'\n',
#  b'1 Kings 3 p. 525 \n',
#  b'\n',
#  b'1 Kings 4 p. 527 \n',
#  b'\n',
#  b'1 Kings 5 p. 528 \n',
#  b'\n',
#  b'1 Kings 6 p. 529 \n',
#  b'\n',
#  b'1 Kings 7 p. 531 \n',
#  b'\n',
#  b'1 Kings 8 p. 534 \n',
#  b'\n',
#  b'1 Kings 9 p. 538 \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'X \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'1 Kings 10 p. 540 \n',
#  b'\n',
#  b'1 Kings 11 p. 542 \n',
#  b'\n',
#  b'1 Kings 12 p. 544 \n',
#  b'\n',
#  b'1 Kings 13 p. 547 \n',
#  b'\n',
#  b'1 Kings 14 p. 549 \n',
#  b'\n',
#  b'1 Kings 15 p. 550 \n',
#  b'\n',
#  b'1 Kings 16 p. 552 \n',
#  b'\n',
#  b'1 Kings 17 p. 555 \n',
#  b'\n',
#  b'1 Kings 18 p. 556 \n',
#  b'\n',
#  b'1 Kings 19 p. 559 \n',
#  b'\n',
#  b'1 Kings 20 p. 560 \n',
#  b'\n',
#  b'1 Kings 21 p. 563 \n',
#  b'\n',
#  b'1 Kings 22 p. 564 \n',
#  b'\n',
#  b'2 Kings p. 567 \n',
#  b'\n',
#  b'2 Kings 1 p. 568 \n',
#  b'\n',
#  b'2 Kings 2 p. 569 \n',
#  b'\n',
#  b'2 Kings 3 p. 570 \n',
#  b'\n',
#  b'2 Kings 4 p. 572 \n',
#  b'\n',
#  b'2 Kings 5 p. 575 \n',
#  b'\n',
#  b'2 Kings 6 p. 576 \n',
#  b'\n',
#  b'2 Kings 7 p. 578 \n',
#  b'\n',
#  b'2 Kings 8 p. 580 \n',
#  b'\n',
#  b'2 Kings 9 p. 582 \n',
#  b'\n',
#  b'2 Kings 10 p. 584 \n',
#  b'\n',
#  b'2 Kings 11 p. 586 \n',
#  b'\n',
#  b'2 Kings 12 p. 588 \n',
#  b'\n',
#  b'2 Kings 13 p. 589 \n',
#  b'\n',
#  b'2 Kings 14 p. 590 \n',
#  b'\n',
#  b'2 Kings 15 p. 592 \n',
#  b'\n',
#  b'2 Kings 16 p. 595 \n',
#  b'\n',
#  b'2 Kings 17 p. 596 \n',
#  b'\n',
#  b'2 Kings 18 p. 598 \n',
#  b'\n',
#  b'2 Kings 19 p. 601 \n',
#  b'\n',
#  b'2 Kings 20 p. 603 \n',
#  b'\n',
#  b'2 Kings 21 p. 604 \n',
#  b'\n',
#  b'2 Kings 22 p. 606 \n',
#  b'\n',
#  b'2 Kings 23 p. 607 \n',
#  b'\n',
#  b'2 Kings 24 p. 610 \n',
#  b'\n',
#  b'2 Kings 25 p. 61 1 \n',
#  b'\n',
#  b'1 Chronicles p. 613 \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'XI \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'1 Chronicles 1 p. 613 \n',
#  b'\n',
#  b'1 Chronicles 2 p. 615 \n',
#  b'\n',
#  b'1 Chronicles 3 p. 617 \n',
#  b'\n',
#  b'1 Chronicles 4 p. 618 \n',
#  b'\n',
#  b'1 Chronicles 5 p. 620 \n',
#  b'\n',
#  b'1 Chronicles 6 p. 622 \n',
#  b'\n',
#  b'1 Chronicles 7 p. 625 \n',
#  b'\n',
#  b'1 Chronicles 8 p. 627 \n',
#  b'\n',
#  b'1 Chronicles 9 p. 628 \n',
#  b'\n',
#  b'1 Chronicles 10 p. 630 \n',
#  b'\n',
#  b'1 Chronicles 11 p. 631 \n',
#  b'\n',
#  b'1 Chronicles 12 p. 633 \n',
#  b'\n',
#  b'1 Chronicles 13 p. 635 \n',
#  b'\n',
#  b'1 Chronicles 14 p. 636 \n',
#  b'\n',
#  b'1 Chronicles 15 p. 637 \n',
#  b'\n',
#  b'1 Chronicles 16 p. 639 \n',
#  b'\n',
#  b'1 Chronicles 17 p. 641 \n',
#  b'\n',
#  b'1 Chronicles 18 p. 643 \n',
#  b'\n',
#  b'1 Chronicles 19 p. 644 \n',
#  b'\n',
#  b'1 Chronicles 20 p. 645 \n',
#  b'\n',
#  b'1 Chronicles 21 p. 646 \n',
#  b'\n',
#  b'1 Chronicles 22 p. 648 \n',
#  b'\n',
#  b'1 Chronicles 23 p. 649 \n',
#  b'\n',
#  b'1 Chronicles 24 p. 651 \n',
#  b'\n',
#  b'1 Chronicles 25 p. 652 \n',
#  b'\n',
#  b'1 Chronicles 26 p. 653 \n',
#  b'\n',
#  b'1 Chronicles 27 p. 655 \n',
#  b'\n',
#  b'1 Chronicles 28 p. 656 \n',
#  b'\n',
#  b'1 Chronicles 29 p. 658 \n',
#  b'\n',
#  b'2 Chronicles p. 660 \n',
#  b'\n',
#  b'2 Chronicles 1 p. 660 \n',
#  b'\n',
#  b'2 Chronicles 2 p. 661 \n',
#  b'\n',
#  b'2 Chronicles 3 p. 662 \n',
#  b'\n',
#  b'2 Chronicles 4 p. 663 \n',
#  b'\n',
#  b'2 Chronicles 5 p. 665 \n',
#  b'\n',
#  b'2 Chronicles 6 p. 666 \n',
#  b'\n',
#  b'2 Chronicles 7 p. 668 \n',
#  b'\n',
#  b'2 Chronicles 8 p. 670 \n',
#  b'\n',
#  b'2 Chronicles 9 p. 671 \n',
#  b'\n',
#  b'2 Chronicles 10 p. 672 \n',
#  b'\n',
#  b'xii \n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'\n',
#  b'The American Standard Version of the Holy Bible (1 901 ) Anonymous \n',
#  b'\n',
#  b'2 Chronicles 11 p. 674 \n',
#  b'\n',
#  b'2 Chronicles 12 p. 675 \n',
#  b'\n',
#  b'2 Chronicles 13 p. 676 \n',
#  b'\n',
#  b'2 Chronicles 14 p. 677 \n',
#  b'\n',
#  b'2 Chronicles 15 p. 678 \n',
#  b'\n',
#  b'2 Chronicles 16 p. 679 \n',
#  b'\n',
#  b'2 Chronicles 17 p. 680 \n',
#  b'\n',
#  b'2 Chronicles 18 p. 681 \n',
#  b'\n',
#  b'2 Chronicles 19 p. 683 \n',
#  b'\n',
#  b'2 Chronicles 20 p. 684 \n',
#  b'\n',
#  b'2 Chronicles 21 p. 686 \n',
#  b'\n',
#  b'2 Chronicles 22 p. 687 \n',
#  b'\n',
#  b'2 Chronicles 23 p. 688 \n',
#  b'\n',
#  b'2 Chronicles 24 p. 690 \n',
#  b'\n',
#  b'2 Chronicles 25 p. 691 \n',
#  b'\n',
#  b'2 Chronicles 26 p. 693 \n',
#  b'\n',
#  b'2 Chronicles 27 p. 695 \n',
#  b'\n',
#  b'2 Chronicles 28 p. 695 \n',
#  b'\n',
#  b'2 Chronicles 29 p. 697 \n',
#  b'\n',
#  b'2 Chronicles 30 p. 699 \n',
#  b'\n',
#  b'2 Chronicles 31 p. 701 \n',
#  b'\n',
#  b'2 Chronicles 32 p. 702 \n',
#  b'\n',
#  b'2 Chronicles 33 p. 705 \n',
#  b'\n',
#  b'2 Chronicles 34 p. 706 \n',
#  b'\n',
#  b'2 Chronicles 35 p. 708 \n',
#  b'\n',
#  b'2 Chronicles 36 p. 710 \n',
#  b'\n',
#  b'Ezra p. 712 \n',
#  b'\n',
#  b'Ezra 1 p. 712 \n',
#  b'\n',
#  b'Ezra 2 p. 712 \n',
#  b'\n',
#  b'Ezra 3 p. 715 \n',
#  b'\n',
#  b'Ezra 4 p. 716 \n',
#  b'\n',
#  ...]
