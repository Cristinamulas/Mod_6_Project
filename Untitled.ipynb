# %%
import pandas as pd

# %%
koran = pd.read_csv('English2Quran.csv')

# %%
koran.describe()
# Out:
#                                  1|1|In the name of Allah  Most Gracious  \
# count                                                6161           4271
# unique                                               6161           3849
# top     46|18|Such are they against whom is proved the...         #NAME?
# freq                                                    1            169
#
#         Most Merciful. Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# count             2466       1296        670        367        198        111
# unique            2233       1166        623        344        183        104
# top             #NAME?     #NAME?     #NAME?          -     #NAME?     #NAME?
# freq                96         52         20         10          8          5
#
#                                            Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# count                                              61         38          22
# ...

# %%
koran[]
